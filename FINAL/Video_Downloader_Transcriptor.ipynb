# %%
from tkinter import *
from tkinter import ttk
from pytube import YouTube
from PIL import Image, ImageTk
import urllib.request
import threading
import moviepy.editor
import speech_recognition as sr
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pydub.utils import make_chunks
import string
from googletrans import Translator

# %%
root = Tk()
root.title("Video to Audio to Text")
root.geometry('650x450')
root.resizable(False, False)
# Out:
# ''

# %%
# video_thumbnail_frame = Frame(root, highlightbackground="black", highlightthickness=.1)
video_thumbnail_frame = Frame(root, relief = SUNKEN, bd = 1, width = 325, height = 200)
video_information_frame = LabelFrame(root, text = "Video Information", width = 325, height = 200)
video_url_frame = Frame(root, height = "80")
video_audio_frame = Frame(root, background="#F5C2C1")

# %%
video_thumbnail_frame.grid(row=0, column=0, sticky="nsew", padx=2, pady=2)
video_information_frame.grid(row=0, column=1, sticky="nsew", padx=2, pady=2)
video_url_frame.grid(row=1, column=0, columnspan=2, sticky="nsew", padx=2, pady=2)
video_audio_frame.grid(row=2, column=0, columnspan=2, sticky="nsew", padx=2, pady=2)

# %%
video_thumbnail_image_label = Label(video_thumbnail_frame)
video_thumbnail_image_label.place(anchor = "center", relx = .5, rely = .5)

# %%
video_title_label = Label(video_information_frame, text = "Video Title: ")
video_title_label.place(anchor = "w", relx = .01, rely = .12)
video_author_label = Label(video_information_frame, text = "Video By: ")
video_author_label.place(anchor = "w", relx = .01, rely = .30)
video_view_label = Label(video_information_frame, text = "Video View Count: ")
video_view_label.place(anchor = "w", relx = .01, rely = .45)
video_publish_label = Label(video_information_frame, text = "Video Publish Date: ")
video_publish_label.place(anchor = "w", relx = .01, rely = .60)
video_id_label = Label(video_information_frame, text = "Video ID: ")
video_id_label.place(anchor = "w", relx = .01, rely = .75)

# %%
url_label = Label(video_url_frame, text = "Enter Video URL: ")
url_label.place(anchor="w", relx=.08, rely=.5)
urlInput = Entry(video_url_frame, borderwidth=15, relief = FLAT)
urlInput.place(anchor="c", relx=.5, rely=.5, width=300, height=25)
url_done_btn = Button(video_url_frame, text = "DONE", command = lambda:get_video_info(urlInput.get()))
url_done_btn.place(anchor="e", relx=.85, rely=.5)

# %%
stop_thread = threading.Event()

# %%
def get_video_info(link):
    
    global video_thumbnail_image_label
    global video_desc_label
    global img
    global video_download_ongoing_label
    global audio_text_download_ongoing_label
    global download_video_btn
    global convert_video_to_text_btn
    
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    video_download_ongoing_label.configure(text = "")
    audio_text_download_ongoing_label.configure(text = "")
    
    video = YouTube(link, use_oauth=True, allow_oauth_cache=True)
    
    thumbnail_url = video.thumbnail_url
    
    urllib.request.urlretrieve(thumbnail_url, "thumbnail.jpg")
    thumbnail_image = Image.open("thumbnail.jpg").resize((325, 200), Image.ANTIALIAS) 
    
    img = ImageTk.PhotoImage(thumbnail_image)
    video_thumbnail_image_label.configure(image = img)
    video_thumbnail_image_label.configure(image = img)
    os.remove("thumbnail.jpg")
    
    video_title = "Video Title: " + video.title + '\n'
    video_author = "Video By: " + video.author + '\n'
    video_view_count = "Video View Count: " + str(video.views) + '\n'
    video_publish_date = "Video Publish Date: " + str(video.publish_date) + '\n'
    video_id = "Video ID: " + video.video_id + '\n'
    
    if len(video_title) >= 53:
        video_title = video_title[:52] + "..."

    video_title_label.configure(text = video_title)
    video_author_label.configure(text = video_author)
    video_view_label.configure(text = video_view_count)
    video_publish_label.configure(text = video_publish_date)
    video_id_label.configure(text = video_id)
    
    stop_thread.clear()

# %%
tab = ttk.Notebook(video_audio_frame)
# tab.place(anchor = 'nw', width = 600, height = 135)
tab.pack(fill = BOTH, expand = 1)

# %%
video_frame = Frame(video_audio_frame, height = 135)
audio_text_frame = Frame(video_audio_frame)

# %%
video_frame.pack()
audio_text_frame.pack()

# %%
tab.add(video_frame, text = "Download Video Only")
tab.add(audio_text_frame, text = "Download Video and Text Convert")

# %%
video_download_ongoing_label = Label(video_frame, text = "", relief = SUNKEN, bd = 1, width = 650, height = 1)
video_download_ongoing_label.place(anchor = "s", relx = 0.5, rely = 1)

# %%
def start_thread_process(num):

    if num == 1:
        video_download_thread = threading.Thread(target = lambda:download_video(urlInput.get()))
        loading_text_thread = threading.Thread(target = lambda:loading_text(1))
        video_download_thread.start()
        loading_text_thread.start()
        
    elif num == 2:
        audio_text_donwload_thread = threading.Thread(target = lambda:convert_video_to_text(urlInput.get(), video_language_cb.current(), audio_slicing_constraint_cb.current()))
        loading_text_thread = threading.Thread(target = lambda:loading_text(2))
        audio_text_donwload_thread.start() 
        loading_text_thread.start()

# %%
def download_video(link):
    global url_done_btn
    global download_video_btn
    global convert_video_to_text_btn
    
    url_done_btn["state"] = DISABLED
    download_video_btn["state"] = DISABLED
    convert_video_to_text_btn["state"] = DISABLED
    
    
    only_video_download_folder = "Downloaded Videoes"
    
    if not os.path.isdir(only_video_download_folder):
        os.mkdir(only_video_download_folder)
    
    video = YouTube(link, use_oauth=True, allow_oauth_cache=True)
    my_video = video.streams.filter(progressive = True, file_extension = 'mp4').get_highest_resolution().download(only_video_download_folder)
#     my_video.download(only_video_download_folder)
    
    stop_thread.set()
    
    url_done_btn["state"] = ACTIVE
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    video_download_ongoing_label.configure(text = "Your Video is Successfully Downloaded")

# %%
def loading_text(num):
    global video_download_ongoing_label
    global audio_text_download_ongoing_label
    
    if num == 1:
        st = "Video Downloading has started...Please Wait---"
        while True:
            video_download_ongoing_label.configure(text = st + "/")
            video_download_ongoing_label.configure(text = st + "-")
            video_download_ongoing_label.configure(text = st + "\\")
            
            if stop_thread.is_set():
                break
                
    elif num == 2:
        st = "Video to Text Conversion ongoing...Please Wait---"
        while True:
            audio_text_download_ongoing_label.configure(text = st + "/")
            audio_text_download_ongoing_label.configure(text = st + "-")
            audio_text_download_ongoing_label.configure(text = st + "\\")
            
            if stop_thread.is_set():
                break

# %%
download_video_btn = Button(video_frame, text = "Download Only Video", command = lambda:start_thread_process(1), state = DISABLED)
download_video_btn.place(anchor = "center", relx = .5, rely = .5)

# %%
choose_video_language_label = Label(audio_text_frame, text = "Choose Video Language: ")
choose_video_language_label.place(anchor = "nw", relx = .02, rely = .2)

video_language = StringVar()

video_language_cb = ttk.Combobox(audio_text_frame, width = 20, textvariable = video_language, state="readonly")
video_language_cb['values'] = (
    ' Bengali - India', 
    ' Bengali - Bangladesh',
    ' Hindi',
    ' English - India',
    ' English - America', 
    ' English - Britain'
)
video_language_cb.place(anchor = "w", relx = .05, rely = .5)
video_language_cb.current(1)
# Out:
# ''

# %%
choose_video_language_label = Label(audio_text_frame, text = "Choose Audio Slicing Technique: ")
choose_video_language_label.place(anchor = "nw", relx = .32, rely = .2)

audio_slicing = StringVar()

audio_slicing_constraint_cb = ttk.Combobox(audio_text_frame, width = 30, textvariable = audio_slicing, state="readonly")
audio_slicing_constraint_cb['values'] = (
    ' Silence based - 500ms (recommended)', 
    ' Silence based - 250ms',
    ' Silence based - 200ms',
    ' Silence based - 100ms',
    ' Silence based - 50ms', 
    ' Time based - 1.5 min',
    ' Time based - 1 min',
    ' Time based - 50 sec',
    ' Time based - 40sec',
    ' Time based - 20sec'
)
audio_slicing_constraint_cb.place(anchor = "center", relx = .5, rely = .5)
audio_slicing_constraint_cb.current(0)
# Out:
# ''

# %%
audio_text_download_ongoing_label = Label(audio_text_frame, text = "", relief = SUNKEN, bd = 1, width = 650, height = 1)
audio_text_download_ongoing_label.place(anchor = "s", relx = 0.5, rely = 1)

# %%
convert_video_to_text_btn = Button(audio_text_frame, text = "Download Video\n And\n Convert to Text", command = lambda:start_thread_process(2), state = DISABLED)
convert_video_to_text_btn.place(anchor = "e", relx = .9, rely = .5)

# %%
def convert_video_to_text(link, lang_index, chunk_index):
    
    global url_done_btn
    global download_video_btn
    global convert_video_to_text_btn
    
    url_done_btn["state"] = DISABLED
    download_video_btn["state"] = DISABLED
    convert_video_to_text_btn["state"] = DISABLED
    
    video = YouTube(link, use_oauth=True, allow_oauth_cache=True)
    
    folder_name = video.title.translate(str.maketrans('', '', string.punctuation))
    
    folder_name = folder_name[:50].strip()
    
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    
    my_video = video.streams.get_highest_resolution().download(folder_name)
    os.rename(my_video, os.path.join(folder_name, "video.mp4"))
    
    
    downloaded_video = moviepy.editor.VideoFileClip(os.path.join(folder_name, "video.mp4"))
   
    
    audio = downloaded_video.audio
    audio.write_audiofile(os.path.join(folder_name, "audio.wav"))
    
    whole_text_pronounce = get_large_audio_transcription(folder_name, os.path.join(folder_name, "audio.wav"), lang_index, chunk_index)
    
    if(lang_index == 2):
        string_divide = whole_text_pronounce.split("<---|---|--->")
        
        text_filename_1 = os.path.join(folder_name, "final(pronounce).txt")
    
        f1 = open(text_filename_1, "x", encoding="utf-8")
        f1 = open(text_filename_1, "r+", encoding="utf-8")
        f1.write(string_divide[0])
        f1.close()
        
        translated_hindi_text = hindi_translation(string_divide[1])
        
        text_filename_2 = os.path.join(folder_name, "final(hindi_translated).txt")
    
        f2 = open(text_filename_2, "x", encoding="utf-8")
        f2 = open(text_filename_2, "r+", encoding="utf-8")
        f2.write(translated_hindi_text)
        f2.close()
        
    else:
        
        text_filename = os.path.join(folder_name, "final(pronounce).txt")
    
        f = open(text_filename, "x", encoding="utf-8")
        f = open(text_filename, "r+", encoding="utf-8")
        f.write(whole_text_pronounce)
        f.close()
    
     
    
    stop_thread.set()
    
    url_done_btn["state"] = ACTIVE
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    audio_text_download_ongoing_label.configure(text = "Your Video-Audio is Successfully Converted to Text")

# %%
def get_large_audio_transcription(parent_folder, audio_path, lang_index, chunk_index):
    
    rec = sr.Recognizer()
    sound = AudioSegment.from_wav(audio_path)
    
    if(chunk_index == 0):
        chunks = split_on_silence(sound, min_silence_len = 500, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 1):
        chunks = split_on_silence(sound, min_silence_len = 250, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 2):
        chunks = split_on_silence(sound, min_silence_len = 200, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 3):
        chunks = split_on_silence(sound, min_silence_len = 100, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 4):
        chunks = split_on_silence(sound, min_silence_len = 50, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 5):
        chunks = make_chunks(sound, 90000)
    elif(chunk_index == 6):
        chunks = make_chunks(sound, 60000)
    elif(chunk_index == 6):
        chunks = make_chunks(sound, 50000)
    elif(chunk_index == 7):
        chunks = make_chunks(sound, 40000)
    else:
        chunks = make_chunks(sound, 20000)
    
    folder_name = "audio_chunks"
    folder_path = os.path.join(parent_folder, folder_name)
    if not os.path.isdir(folder_path):
        os.mkdir(folder_path)
    whole_text = ""
    whole_hindi_text = ""
    for i, audio_chunk in enumerate(chunks, start = 1):
        chunk_filename = os.path.join(folder_path, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = rec.record(source)
            
            try:
                if(lang_index == 0):
                    text = rec.recognize_google(audio_listened, language = "bn-IN")
                elif(lang_index == 1):
                    text = rec.recognize_google(audio_listened, language = "bn-BD")
                elif(lang_index == 2):
                    text = rec.recognize_google(audio_listened, language = "en-IN")
                    text_trans = rec.recognize_google(audio_listened, language = "hi-IN")
                elif(lang_index == 3):
                    text = rec.recognize_google(audio_listened, language = "en-IN")
                elif(lang_index == 4):
                    text = rec.recognize_google(audio_listened, language = "en-US")
                else:
                    text = rec.recognize_google(audio_listened, language = "en-GB")
                
            except sr.UnknownValueError as e:
                print("Error: str(e)")
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text + '\n\n'
                if(lang_index == 2):
                    whole_hindi_text += text_trans + '\n\n'
                        
    if(lang_index == 2):
        final_text = whole_text + '\n\n<---|---|--->\n\n' + whole_hindi_text
        return final_text
    
    # return the text for all chunks detected
    return whole_text

# %%
def hindi_translation(hindi_text_whole):
    translated_hindi_to_eng_whole = ""
    hindi_text_whole_divided_list = hindi_text_whole.split("\n\n")
    
    for i in range(len(hindi_text_whole_divided_list)):
        
        translator = Translator(service_urls=['translate.googleapis.com'])
        print(hindi_text_whole_divided_list[i])
        trans = translator.translate(hindi_text_whole_divided_list[i], dest='en')
        translated_hindi_to_eng_whole += trans.text + '\n\n'
    
    return translated_hindi_to_eng_whole

# %%
root.mainloop()
# Out:
# MoviePy - Writing audio in 8bit computer update\audio.wav
# MoviePy - Done.
# result2:
# {   'alternative': [   {   'transcript': '7% I uploaded a few videos of this '
#                                          'program will computer that I told a '
#                                          'while AG'},
#                        {   'transcript': '7% I uploaded a few videos of this '
#                                          'program will computer that I told a '
#                                          'while'},
#                        {   'transcript': '7% I upload a few videos of this '
#                                          'program will computer that I told a '
#                                          'while AG'},
#                        {   'transcript': '7% I upload a few videos of this '
#                                          'program will computer that I told a '
#                                          'while'},
#                        {   'transcript': '7% I uploaded a few videos of this '
#                                          'program will computer that I told a '
#                                          'while a'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk1.wav : 7% i uploaded a few videos of this program will computer that i told a while ag.
# result2:
# {   'alternative': [   {   'transcript': 'convert questions about it in order '
#                                          'to answer a few of the most common '
#                                          'questions in definitely buy for the '
#                                          'most common question is can you show '
#                                          'us how to download something along '
#                                          'those Lines lines for for this thing '
#                                          'I'},
#                        {   'transcript': 'convert questions about it in order '
#                                          'to answer a few of the most common '
#                                          'questions in definitely buy for the '
#                                          'most common question is can you show '
#                                          'us how to download something along '
#                                          'those Lines lines for this thing I'},
#                        {   'transcript': 'convert questions about it in order '
#                                          'to answer a few of the most common '
#                                          'questions in definitely buy for the '
#                                          'most common question is can you show '
#                                          'us how to download something along '
#                                          'those Lines lines for for this '
#                                          'thing'},
#                        {   'transcript': 'convert questions about it in order '
#                                          'to answer a few of the most common '
#                                          'questions in definitely buy for the '
#                                          'most common question is can you show '
#                                          'us how to download something along '
#                                          'those Lines lines for this thing'},
#                        {   'transcript': 'convert questions about it in order '
#                                          'to answer a few of the most common '
#                                          'questions in definitely buy for the '
#                                          'most common question is can you show '
#                                          'us how to download something along '
#                                          'those Lines lines for for this '
#                                          'time'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk2.wav : Convert questions about it in order to answer a few of the most common questions in definitely buy for the most common question is can you show us how to download something along those lines lines for for this thing i.
# result2:
# {   'alternative': [   {'transcript': 'full screen architecture is piece of'},
#                        {'transcript': 'full screen architecture is'},
#                        {'transcript': 'full screen architecture is peace of'},
#                        {'transcript': 'full screen architecture is pieces'},
#                        {'transcript': 'full screen architecture is PC'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk3.wav : Full screen architecture is piece of.
# result2:
# {   'alternative': [   {   'transcript': 'and you know about interesting '
#                                          'experiment with you know one model '
#                                          'of the time before and put it all '
#                                          "together it wasn't really until all "
#                                          'the pieces came together'},
#                        {   'transcript': 'and you know about interesting '
#                                          'experiment with you know one model '
#                                          'of the time before I put it all '
#                                          "together it wasn't really until all "
#                                          'the pieces came together'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk4.wav : And you know about interesting experiment with you know one model of the time before and put it all together it wasn't really until all the pieces came together.
# result2:
# []
# Error: str(e)
# result2:
# {'alternative': [{'transcript': 'work'}], 'final': True}
# 8bit computer update\audio_chunks\chunk6.wav : Work.
# result2:
# {   'alternative': [   {   'transcript': 'follow in this book that I will '
#                                          "recommend that you don't Computer "
#                                          'Electronics by Albert you know'},
#                        {   'transcript': 'follow in this book that I will '
#                                          "recommend that you don't Computer "
#                                          'Electronics by Albert we know'},
#                        {   'transcript': 'follow in this book that I will '
#                                          "recommend that you don't Computer "
#                                          'Electronics by Albert you know '
#                                          'print'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk7.wav : Follow in this book that i will recommend that you don't computer electronics by albert you know.
# result2:
# {   'alternative': [   {   'transcript': 'here if you want to find a copy of '
#                                          'you can find the use copy online or '
#                                          'something'},
#                        {   'transcript': 'if you want to find a copy of you '
#                                          'can find the use copy online or '
#                                          'something'},
#                        {   'transcript': 'here if you want to find a copy of '
#                                          'you can find a used'},
#                        {   'transcript': 'if you want to find a copy of you '
#                                          'can find a used'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk8.wav : Here if you want to find a copy of you can find the use copy online or something.
# result2:
# {   'alternative': [   {   'transcript': 'in architecture has cupboard that is '
#                                          'one is the sap1 which is simple as '
#                                          'possible'},
#                        {   'transcript': 'Yes Papa in architecture has '
#                                          'cupboard that is one is the sap1 '
#                                          'which is simple as possible'},
#                        {   'transcript': 'in architecture has cupboard that is '
#                                          'one is the SAP 1 which is simple as '
#                                          'possible'},
#                        {   'transcript': 'Yes Papa in architecture has '
#                                          'cupboard that is one is the SAP 1 '
#                                          'which is simple as possible'},
#                        {   'transcript': 'in architecture has cupboard that is '
#                                          'one is the SAP one which is simple '
#                                          'as possible'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk9.wav : In architecture has cupboard that is one is the sap1 which is simple as possible.
# result2:
# {   'alternative': [   {   'transcript': 'is is to be a very simple computer '
#                                          'architecture of the demonstrates in '
#                                          'all the crucial ideas buying '
#                                          'computer operation without being in '
#                                          'any more complicated and needs to '
#                                          'be'},
#                        {   'transcript': 'is is to be a very simple computer '
#                                          'architecture of the demonstrates in '
#                                          'all the crucial ideas buying '
#                                          'computer operation without being in '
#                                          'any more complicated than any needs '
#                                          'to be'},
#                        {   'transcript': 'is is to be a very simple computer '
#                                          'architecture of the demonstrates in '
#                                          'all the crucial ideas buying '
#                                          'computer operation without being in '
#                                          'any more complicated than it needs '
#                                          'to be'},
#                        {   'transcript': 'is is to be a very simple computer '
#                                          'architecture of the demonstrates in '
#                                          'all the crucial ideas buying '
#                                          'computer operation without being in '
#                                          'any more complicated and needs to '
#                                          'the'},
#                        {   'transcript': 'is is to be a very simple computer '
#                                          'architecture of the demonstrates in '
#                                          'all the crucial ideas buying '
#                                          'computer operation without being in '
#                                          'any more complicated and need to '
#                                          'be'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk10.wav : Is is to be a very simple computer architecture of the demonstrates in all the crucial ideas buying computer operation without being in any more complicated and needs to be.
# result2:
# {   'alternative': [   {'transcript': 'the frequency'},
#                        {'transcript': 'the vacancy'},
#                        {'transcript': 'the frequency the'},
#                        {'transcript': 'the second season'},
#                        {'transcript': 'hey Siri can see the'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk11.wav : The frequency.
# result2:
# {   'alternative': [   {   'transcript': 'architecture that they have in here '
#                                          'is is basically the model that I '
#                                          'followed on what I paste this '
#                                          'computer on'},
#                        {   'transcript': 'architecture that they have in here '
#                                          'is is basically the model that I '
#                                          'followed on what I was this computer '
#                                          'on'},
#                        {   'transcript': 'architecture that they have in here '
#                                          'is is basically the model that I '
#                                          'followed on what I paste this '
#                                          'computer Run'},
#                        {   'transcript': 'architecture that they have in here '
#                                          'is is basically the model that I '
#                                          'followed on what I say this computer '
#                                          'on'},
#                        {   'transcript': 'architecture that they have in here '
#                                          'is is basically the model that I '
#                                          'followed on what I was this computer '
#                                          'Run'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk12.wav : Architecture that they have in here is is basically the model that i followed on what i paste this computer on.
# result2:
# {   'alternative': [   {   'transcript': 'so you can see all the same '
#                                          'components that is a program cannot '
#                                          'hear'},
#                        {   'transcript': 'so you can see all the same '
#                                          'components are there is a program '
#                                          'cannot hear'},
#                        {   'transcript': 'so you can see all the same '
#                                          'components are there is a program '
#                                          'counter here'},
#                        {   'transcript': 'so you can see all the same '
#                                          'components are there is a program '
#                                          'cannot here'},
#                        {   'transcript': 'so you can see all the same '
#                                          'components that is a program cannot '
#                                          'here'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk13.wav : So you can see all the same components that is a program cannot hear.
# result2:
# {   'alternative': [   {'transcript': 'there is the memory address register'},
#                        {'transcript': 'there is a memory address register'},
#                        {'transcript': "there's the memory address register"},
#                        {'transcript': 'there is some memory address register'},
#                        {'transcript': "there's a memory address register"}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk14.wav : There is the memory address register.
# result2:
# {   'alternative': [   {'transcript': '16 bytes of memory'},
#                        {'transcript': '16 bytes of memory used'},
#                        {'transcript': '16 bytes of memory YouTube'},
#                        {'transcript': '16 bytes of memory us'},
#                        {'transcript': '16 bytes of memory unit'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk15.wav : 16 bytes of memory.
# result2:
# {   'alternative': [   {'transcript': 'horror movie'},
#                        {'transcript': 'horror movie download'},
#                        {'transcript': 'horror movies'},
#                        {'transcript': 'horror movie downloading'},
#                        {'transcript': 'horror movies download'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk16.wav : Horror movie.
# result2:
# {   'alternative': [   {'transcript': 'same same difference'},
#                        {'transcript': 'say something different'},
#                        {'transcript': 'same same different'},
#                        {'transcript': 'same thing difference'},
#                        {'transcript': 'same thing different'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk17.wav : Same same difference.
# result2:
# {   'alternative': [   {'transcript': 'answers NCERT operations concer'},
#                        {'transcript': 'answers NCERT operation the concer'},
#                        {'transcript': 'answers NCERT operations'},
#                        {'transcript': 'answers NCERT operation theatre'},
#                        {'transcript': 'answers NCERT operation to concer'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk18.wav : Answers ncert operations concer.
# result2:
# {'alternative': [{'transcript': 'instruction register'}], 'final': True}
# 8bit computer update\audio_chunks\chunk19.wav : Instruction register.
# result2:
# {   'alternative': [   {   'transcript': 'you can see they have all these '
#                                          'signals going out that come back and '
#                                          'all the other components are all the '
#                                          'control signal'},
#                        {   'transcript': 'you can see they have all these '
#                                          'signals going out that come back and '
#                                          'all the other components of the '
#                                          'control signal'},
#                        {   'transcript': 'you can see they have all these '
#                                          'signals going out that come back and '
#                                          'all the other components all the '
#                                          'control signal'},
#                        {   'transcript': 'you can see they have all these '
#                                          'signals going out that come back and '
#                                          'all the other components are the '
#                                          'control signal'},
#                        {   'transcript': 'you can see they have all these '
#                                          'signals going out that come back and '
#                                          'all the other components of all the '
#                                          'control signal'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk20.wav : You can see they have all these signals going out that come back and all the other components are all the control signal.
# result2:
# {   'alternative': [   {   'transcript': 'I come from the control unit and go '
#                                          'out all the three pieces to the work '
#                                          'experience'},
#                        {   'transcript': 'I come from the control unit and go '
#                                          'out all the three pieces of the work '
#                                          'experience'},
#                        {   'transcript': 'I come from the control unit and go '
#                                          'out all the three pieces of work '
#                                          'experience'},
#                        {   'transcript': 'I come from the control unit and go '
#                                          'out all the three pieces to the work '
#                                          'experience everything'},
#                        {   'transcript': 'I come from the control unit and go '
#                                          'out all the three pieces of work '
#                                          'experience everything'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk21.wav : I come from the control unit and go out all the three pieces to the work experience.
# result2:
# {   'alternative': [   {'transcript': 'which is the average of here'},
#                        {'transcript': 'accumulator which is the average'},
#                        {'transcript': 'which is the average here'},
#                        {'transcript': 'which is the average of hair'},
#                        {'transcript': 'which is the average hair'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk22.wav : Which is the average of here.
# result2:
# {   'alternative': [   {   'transcript': 'the area which is the Arithmetic and '
#                                          'logic unit which in this computer'},
#                        {   'transcript': 'the area which is the Arithmetic and '
#                                          'logic unit which in this computer '
#                                          'subject'},
#                        {   'transcript': 'the area which is the Arithmetic and '
#                                          'logic unit which in the computer '
#                                          'subject'},
#                        {   'transcript': 'the area which is the Arithmetic and '
#                                          'logic unit which in the computer'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk23.wav : The area which is the arithmetic and logic unit which in this computer.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'transcript': 'han maine To Be registered to the '
#                                          'end of the register of the inputs '
#                                          'for the Arithmetic'},
#                        {   'transcript': 'han maine to be registered the '
#                                          'inputs for the Arithmetic'},
#                        {   'transcript': 'han maine To Be registered to the '
#                                          'end of the inputs for the '
#                                          'Arithmetic'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk25.wav : Han maine to be registered to the end of the register of the inputs for the arithmetic.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'transcript': "and that's want to help me to this "
#                                          'as well primarily around the '
#                                          'instructions that what you can '
#                                          'actually do with it'},
#                        {   'transcript': "and that's want to help me to this "
#                                          'as well primarily around the '
#                                          'instruction set what you can '
#                                          'actually do with it'},
#                        {   'transcript': "and that's want to help me to this "
#                                          'as well primarily around the '
#                                          'instructions that what you can '
#                                          'actually do with that'},
#                        {   'transcript': "and that's want to help me to this "
#                                          'as well primarily around the '
#                                          'instruction set what you can '
#                                          'actually do with that'},
#                        {   'transcript': "and that's want to help me to this "
#                                          'as well primarily around the '
#                                          'instructions that what you can '
#                                          'actually do is it'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk27.wav : And that's want to help me to this as well primarily around the instructions that what you can actually do with it.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'transcript': 'instructions having a load '
#                                          'instruction and instruction'},
#                        {   'transcript': 'instructions having a load '
#                                          'instruction in and instruction'},
#                        {   'transcript': 'instructions having a load '
#                                          'instruction in an instruction'},
#                        {   'transcript': 'instructions having a lot of '
#                                          'instruction and instruction'},
#                        {   'transcript': 'instructions having a lot '
#                                          'instruction and instruction'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk29.wav : Instructions having a load instruction and instruction.
# result2:
# {'alternative': [{'transcript': 'sub'}, {'transcript': 'Sutra'}], 'final': True}
# 8bit computer update\audio_chunks\chunk30.wav : Sub.
# result2:
# {'alternative': [{'transcript': 'top horror'}], 'final': True}
# 8bit computer update\audio_chunks\chunk31.wav : Top horror.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {'transcript': 'in addition to the download'},
#                        {'transcript': 'in addition to the delivery'},
#                        {'transcript': 'in addition to the download a'},
#                        {'transcript': 'in addition to the downloader'},
#                        {'transcript': 'in addition to the downloaded'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk33.wav : In addition to the download.
# result2:
# {   'alternative': [   {   'transcript': 'two memories that again more Complex '
#                                          'programs'},
#                        {   'transcript': 'two memories that again more Complex '
#                                          'program'},
#                        {'transcript': 'again more Complex programs'},
#                        {'transcript': 'more Complex programs'},
#                        {'transcript': 'again more Complex program'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk34.wav : Two memories that again more complex programs.
# result2:
# {   'alternative': [   {   'transcript': 'important for a program of computer '
#                                          'and other jump instruction and '
#                                          "there's also a conditional jump "
#                                          'instruction that jumps when the '
#                                          'Caribbean is'},
#                        {   'transcript': 'important for a program of computer '
#                                          'and other jump instruction and '
#                                          "there's also a condition of "
#                                          'instruction that jumps when the '
#                                          'Caribbean is'},
#                        {   'transcript': 'important for a program of computer '
#                                          'and other jump instruction and '
#                                          "there's also a conditional champion "
#                                          'is'},
#                        {   'transcript': 'important for a program of computer '
#                                          'and other jump instruction and there '
#                                          'is also a conditional champion is'},
#                        {   'transcript': 'important for a program of computer '
#                                          'and other jump instruction and '
#                                          "there's also a conditional "
#                                          'champion'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk35.wav : Important for a program of computer and other jump instruction and there's also a conditional jump instruction that jumps when the caribbean is.
# result2:
# {   'alternative': [   {'transcript': 'how many times'},
#                        {'transcript': 'how many time'},
#                        {'transcript': 'how many times the'},
#                        {'transcript': 'alarm any time'},
#                        {'transcript': 'how many time the'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk36.wav : How many times.
# result2:
# {   'alternative': [   {'transcript': 'the addition over flowers'},
#                        {'transcript': 'the addition of a false'},
#                        {'transcript': 'the edition over flowers'},
#                        {'transcript': 'the addition of a house'},
#                        {'transcript': 'the addition of a force'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk37.wav : The addition over flowers.
# result2:
# {   'alternative': [   {   'transcript': 'you stole my be wondering ok can I '
#                                          'just tell you how to build this '
#                                          'thing I really can you draw that is '
#                                          'exactly right time to do is to make '
#                                          'a bunch of videos that go through '
#                                          'every step of the process'},
#                        {   'transcript': 'you stole my be wondering ok can I '
#                                          'just tell you how to build this '
#                                          'thing I really can you draw that is '
#                                          'exactly right time to do is to make '
#                                          'a bunch of videos they go through '
#                                          'every step of the process'},
#                        {   'transcript': 'you stole my be wondering ok can I '
#                                          'just tell you how to build this '
#                                          'thing I really can you draw that is '
#                                          'exactly right time to do is to make '
#                                          'a bunch of videos they go through '
#                                          'every step in the process'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk38.wav : You stole my be wondering ok can i just tell you how to build this thing i really can you draw that is exactly right time to do is to make a bunch of videos that go through every step of the process.
# result2:
# {   'alternative': [   {   'transcript': 'I am planning to talk about a whole '
#                                          'new copy of this computer from '
#                                          'scratch'},
#                        {   'transcript': 'hi I am planning to talk about a '
#                                          'whole new copy of this computer from '
#                                          'scratch'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk39.wav : I am planning to talk about a whole new copy of this computer from scratch.
# result2:
# {   'alternative': [   {'transcript': 'harm and have videos of available'},
#                        {'transcript': 'I am and have videos of available'},
#                        {'transcript': 'I am and I have videos of available'},
#                        {'transcript': 'I am and have videos of evaluate'},
#                        {'transcript': 'I am and I have videos of evaluate'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk40.wav : Harm and have videos of available.
# result2:
# {   'alternative': [   {'transcript': 'bad news is going to take a while'},
#                        {'transcript': 'bad news is gonna take a while'},
#                        {'transcript': 'bad news is can I take a while'},
#                        {'transcript': 'bad news is going to take away'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk41.wav : Bad news is going to take a while.
# result2:
# {   'alternative': [   {   'transcript': "I don't have a turn off free time on "
#                                          'fortunately but my personal goal is '
#                                          'to make'},
#                        {   'transcript': "I don't have a turn off free time on "
#                                          'fortunately by my personal goal is '
#                                          'to make'},
#                        {   'transcript': "I don't have a turn off free time on "
#                                          'fortunately my personal goal is to '
#                                          'make'},
#                        {   'transcript': "I don't have a turn off free time on "
#                                          'fortunately but my personal goal is '
#                                          'the make'},
#                        {   'transcript': "I don't have a turn off free time on "
#                                          'fortunately by my personal goal is '
#                                          'the make'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk42.wav : I don't have a turn off free time on fortunately but my personal goal is to make.
# result2:
# {   'alternative': [   {'transcript': 'one video weak at a minimum'},
#                        {'transcript': 'one video week at a minimum'},
#                        {'transcript': 'one variable week at a minimum'},
#                        {'transcript': 'one variable'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk43.wav : One video weak at a minimum.
# result2:
# {   'alternative': [   {   'transcript': 'I want to make some covering '
#                                          'everything'},
#                        {   'transcript': "I want to make sure I'm covering "
#                                          'everything'},
#                        {   'transcript': 'I want to make from covering '
#                                          'everything'},
#                        {   'transcript': 'I want to make sure some covering '
#                                          'everything'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk44.wav : I want to make some covering everything.
# result2:
# {   'alternative': [   {   'transcript': 'from first principle Why things work '
#                                          'the way they do'},
#                        {   'transcript': 'from first principle Why things work '
#                                          'the way that they do'},
#                        {   'transcript': 'from first principle Why things what '
#                                          'the way that they do'},
#                        {   'transcript': 'from first principle Why things work '
#                                          'together they do'},
#                        {   'transcript': 'from first principle Why things work '
#                                          'together'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk45.wav : From first principle why things work the way they do.
# result2:
# {   'alternative': [{'transcript': 'ask you to take anything on face'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk46.wav : Ask you to take anything on face.
# result2:
# {   'alternative': [   {   'transcript': "probably means it's going to take a "
#                                          'while to get everything list'},
#                        {   'transcript': "probably means it's going to take a "
#                                          'while to get everything le'},
#                        {   'transcript': "probably means it's going to take a "
#                                          'while to get everything at Le'},
#                        {   'transcript': "probably means it's going to take a "
#                                          'while to get everything please'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk47.wav : Probably means it's going to take a while to get everything list.
# result2:
# {   'alternative': [   {'transcript': 'probably Lon'},
#                        {'transcript': 'yeah list of few months probably Lon'},
#                        {'transcript': 'yeah list a few months probably Lon'},
#                        {'transcript': 'list of few months probably Lon'},
#                        {'transcript': 'probably long'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk48.wav : Probably lon.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {'transcript': 'did anyone can'},
#                        {'transcript': 'anyone can'},
#                        {'transcript': 'that anyone can'},
#                        {'transcript': 'there anyone can'},
#                        {'transcript': 'any one can'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk50.wav : Did anyone can.
# result2:
# {   'alternative': [   {   'transcript': 'you can do this computer I mean is '
#                                          'long as your'},
#                        {   'transcript': 'you can do this computer I mean is '
#                                          'long is your'},
#                        {   'transcript': 'you can tell this computer I mean is '
#                                          'long as your'},
#                        {   'transcript': 'you can do this computer I mean is '
#                                          'language'},
#                        {   'transcript': 'you can do this computer I mean is '
#                                          'long as you'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk51.wav : You can do this computer i mean is long as your.
# result2:
# {   'alternative': [   {   'transcript': "today's station and after viral up "
#                                          'carefully and you have another '
#                                          'persistence to troubleshoot the '
#                                          'inevitable wrong connections are '
#                                          'working conditions anyone can do '
#                                          'this you know and understand really '
#                                          'understand a very deep level how '
#                                          'computer Works By bowling machine '
#                                          "even if you don't have any "
#                                          'experience'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk52.wav : Today's station and after viral up carefully and you have another persistence to troubleshoot the inevitable wrong connections are working conditions anyone can do this you know and understand really understand a very deep level how computer works by bowling machine even if you don't have any experience.
# result2:
# {   'alternative': [   {   'transcript': 'looking forward to that happening in '
#                                          'people people building these things '
#                                          'in improving order even'},
#                        {   'transcript': 'looking forward to that happening in '
#                                          'people people building these things'},
#                        {   'transcript': 'looking forward to that happening in '
#                                          'people people building these things '
#                                          'in improving on a given'},
#                        {   'transcript': 'looking forward to that happening in '
#                                          'people people building these things '
#                                          'and improving order even'},
#                        {   'transcript': 'looking forward to that happening in '
#                                          'people people building these things '
#                                          'and improving on a given'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk53.wav : Looking forward to that happening in people people building these things in improving order even.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'transcript': 'settings for the next next videos '
#                                          'can be travelling over the next week '
#                                          'so maybe maybe in a couple weeks '
#                                          'before and get the next video'},
#                        {   'transcript': 'settings for the next next videos '
#                                          'can be travelling over the next week '
#                                          'so maybe maybe in a couple weeks '
#                                          'before India the next video'},
#                        {   'transcript': 'settings for the next next videos '
#                                          'can be travelling over the next week '
#                                          'so maybe maybe in a couple weeks '
#                                          'before any of the next video'},
#                        {   'transcript': 'settings for the next next videos '
#                                          'can be travelling over the next week '
#                                          'so maybe maybe in a couple weeks '
#                                          'before any other next video'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk55.wav : Settings for the next next videos can be travelling over the next week so maybe maybe in a couple weeks before and get the next video.
# result2:
# {   'alternative': [   {'transcript': 'is the start focusing on the clock'},
#                        {'transcript': 'is to start focusing on the clock'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk56.wav : Is the start focusing on the clock.
# result2:
# {   'alternative': [   {   'transcript': 'as as the first steps and a walk '
#                                          'through in a building this the clock '
#                                          'circuit from scratch in the couple '
#                                          'interesting things going on here the '
#                                          'clock of course coordinates '
#                                          'everything'},
#                        {   'transcript': 'as as the first steps and a walk '
#                                          'through in a building this the clock '
#                                          'circuit from scratch and the couple '
#                                          'interesting things going on here the '
#                                          'clock of course coordinates '
#                                          'everything'},
#                        {   'transcript': 'as as the first steps and a walk '
#                                          'through in a building this the clock '
#                                          'circuit from scratch in the couple '
#                                          'interesting things going on here the '
#                                          'clock cross coordinates everything'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk57.wav : As as the first steps and a walk through in a building this the clock circuit from scratch in the couple interesting things going on here the clock of course coordinates everything.
# result2:
# {   'alternative': [   {'transcript': 'in the computer'},
#                        {'transcript': 'in a computer'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk58.wav : In the computer.
# result2:
# {   'alternative': [   {'transcript': 'the timing of everything'},
#                        {'transcript': 'everything'},
#                        {'transcript': 'the timing'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk59.wav : The timing of everything.
# result2:
# {   'alternative': [   {   'transcript': 'and you can in this case you can '
#                                          'adjust the speed of a clock down'},
#                        {   'transcript': 'and you can in this case you can '
#                                          'adjust the speed of the clock down'},
#                        {   'transcript': 'and you can in this case you can '
#                                          'adjust the speed of a clock at down'},
#                        {   'transcript': 'and you can in this case you can '
#                                          'adjust the speed of a clock'},
#                        {   'transcript': 'and you can in this case you can '
#                                          'adjust the speed of the clock'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk60.wav : And you can in this case you can adjust the speed of a clock down.
# result2:
# {   'alternative': [   {   'transcript': 'everything else ranks lover you can '
#                                          'also'},
#                        {   'transcript': 'everything else ranks flower you can '
#                                          'also'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk61.wav : Everything else ranks lover you can also.
# result2:
# {   'alternative': [   {'transcript': 'stop the clock'},
#                        {'transcript': 'start the clock'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk62.wav : Stop the clock.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'transcript': 'step one step at a time which is '
#                                          'very useful for troubleshooting '
#                                          'something something'},
#                        {   'transcript': 'step one step at a time which is '
#                                          'very useful for troubleshooting '
#                                          'something something something'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk64.wav : Step one step at a time which is very useful for troubleshooting something something.
# result2:
# {   'alternative': [   {   'transcript': 'uses of 555 timer for being used in '
#                                          'a couple different applications in '
#                                          'in the clock circuit'},
#                        {   'transcript': 'uses of 555 timer for being using a '
#                                          'couple different applications in in '
#                                          'the clock circuit'},
#                        {   'transcript': 'uses of 555 timer for being used on '
#                                          'a couple different applications in '
#                                          'in the clock circuit'},
#                        {   'transcript': 'uses of 555 timer for being used as '
#                                          'a couple different applications in '
#                                          'in the clock circuit'},
#                        {   'transcript': 'uses of 555 timer for being used in '
#                                          'a couple different applications in '
#                                          'the clock circuit'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk65.wav : Uses of 555 timer for being used in a couple different applications in in the clock circuit.
# result2:
# {   'alternative': [   {'transcript': 'you can look for the seniors'},
#                        {'transcript': 'you can look for the same those'},
#                        {'transcript': 'you can look for the same nose'},
#                        {'transcript': 'videos you can look for the same nose'},
#                        {'transcript': 'you can look for the Seasons'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk66.wav : You can look for the seniors.
# result2:
# {   'alternative': [   {'transcript': 'I hope it will be worth it'},
#                        {'transcript': "I hope it'll be worth it"},
#                        {'transcript': 'I hope it will be worth that'},
#                        {'transcript': 'I hope will be worth it'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk67.wav : I hope it will be worth it.
# result2:
# {   'alternative': [   {   'transcript': 'fss exciting to you please you know '
#                                          'give this video a thumbs up and '
#                                          'subscribe to the channel tell your '
#                                          'friends'},
#                        {   'transcript': 'fss exciting to you please you know '
#                                          'give this video a thumbs up and '
#                                          'subscribe to the channel tell you '
#                                          'your friends'},
#                        {   'transcript': 'fss exciting to you please you know '
#                                          'give this video a thumbs up and '
#                                          'subscribe to the channel telling '
#                                          'your friends'},
#                        {   'transcript': 'fss exciting to you please you know '
#                                          'give this video a thumbs up and '
#                                          'subscribe to the channel tell me '
#                                          'your friends'},
#                        {   'transcript': 'fss exciting to you please you know '
#                                          'give this video a thumbs up and '
#                                          'subscribe the channel tell you your '
#                                          'friends'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk68.wav : Fss exciting to you please you know give this video a thumbs up and subscribe to the channel tell your friends.
# result2:
# {   'alternative': [   {'transcript': 'if you like what you see'},
#                        {'transcript': 'Iraq is it if you like what you see'},
#                        {'transcript': 'if you like what you say'},
#                        {'transcript': 'Iraq is it if you like what you say'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk69.wav : If you like what you see.
# result2:
# {   'alternative': [   {   'transcript': 'are you doing the people find this '
#                                          'video is really motivating to me so '
#                                          'you know subscribing and watching '
#                                          'the videos is you know ourselves '
#                                          'really the best way to make sure I '
#                                          'keep working on'},
#                        {   'transcript': 'are you doing the people find this '
#                                          'video is really motivating to me so '
#                                          'you know subscribing and watching '
#                                          'the videos is you know I just really '
#                                          'the best way to make sure I keep '
#                                          'working on'},
#                        {   'transcript': 'are you doing the people find this '
#                                          'video is really motivating to me so '
#                                          'you know subscribing and watching '
#                                          'the videos is you know ourselves '
#                                          'really the best way to make sure I '
#                                          'keep working hard'},
#                        {   'transcript': 'are you doing the people find this '
#                                          'video is really motivating to me so '
#                                          'you know subscribing and watching '
#                                          'the videos is you know ourselves '
#                                          'really the best way to make sure I '
#                                          'keep working out'},
#                        {   'transcript': 'are you doing the people find this '
#                                          'video is really motivating to me so '
#                                          'you know subscribing and watching '
#                                          'the videos is you know I just really '
#                                          'the best way to make sure I keep '
#                                          'working hard'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk70.wav : Are you doing the people find this video is really motivating to me so you know subscribing and watching the videos is you know ourselves really the best way to make sure i keep working on.
# result2:
# {   'alternative': [   {'transcript': 'thanks for watching'},
#                        {'transcript': 'so thanks for watching'},
#                        {'transcript': 'chalo thanks for watching'},
#                        {'transcript': 'oh thanks for watching'}],
#     'final': True}
# 8bit computer update\audio_chunks\chunk71.wav : Thanks for watching.
