# %%
from tkinter import *
from tkinter import ttk
from pytube import YouTube
from PIL import Image, ImageTk
import urllib.request
import threading
import moviepy.editor
import speech_recognition as sr
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pydub.utils import make_chunks
import string
from googletrans import Translator

# %%
root = Tk()
root.title("Video to Audio to Text")
root.geometry('650x450')
root.resizable(False, False)
# Out:
# ''

# %%
# video_thumbnail_frame = Frame(root, highlightbackground="black", highlightthickness=.1)
video_thumbnail_frame = Frame(root, relief = SUNKEN, bd = 1, width = 325, height = 200)
video_information_frame = LabelFrame(root, text = "Video Information", width = 325, height = 200)
video_url_frame = Frame(root, height = "80")
video_audio_frame = Frame(root, background="#F5C2C1")

# %%
video_thumbnail_frame.grid(row=0, column=0, sticky="nsew", padx=2, pady=2)
video_information_frame.grid(row=0, column=1, sticky="nsew", padx=2, pady=2)
video_url_frame.grid(row=1, column=0, columnspan=2, sticky="nsew", padx=2, pady=2)
video_audio_frame.grid(row=2, column=0, columnspan=2, sticky="nsew", padx=2, pady=2)

# %%
video_thumbnail_image_label = Label(video_thumbnail_frame)
video_thumbnail_image_label.place(anchor = "center", relx = .5, rely = .5)

# %%
video_title_label = Label(video_information_frame, text = "Video Title: ")
video_title_label.place(anchor = "w", relx = .01, rely = .12)
video_author_label = Label(video_information_frame, text = "Video By: ")
video_author_label.place(anchor = "w", relx = .01, rely = .30)
video_view_label = Label(video_information_frame, text = "Video View Count: ")
video_view_label.place(anchor = "w", relx = .01, rely = .45)
video_publish_label = Label(video_information_frame, text = "Video Publish Date: ")
video_publish_label.place(anchor = "w", relx = .01, rely = .60)
video_id_label = Label(video_information_frame, text = "Video ID: ")
video_id_label.place(anchor = "w", relx = .01, rely = .75)

# %%
url_label = Label(video_url_frame, text = "Enter Video URL: ")
url_label.place(anchor="w", relx=.08, rely=.5)
urlInput = Entry(video_url_frame, borderwidth=15, relief = FLAT)
urlInput.place(anchor="c", relx=.5, rely=.5, width=300, height=25)
url_done_btn = Button(video_url_frame, text = "DONE", command = lambda:get_video_info(urlInput.get()))
url_done_btn.place(anchor="e", relx=.85, rely=.5)

# %%
stop_thread = threading.Event()

# %%
def get_video_info(link):
    
    global video_thumbnail_image_label
    global video_desc_label
    global img
    global video_download_ongoing_label
    global audio_text_download_ongoing_label
    global download_video_btn
    global convert_video_to_text_btn
    
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    video_download_ongoing_label.configure(text = "")
    audio_text_download_ongoing_label.configure(text = "")
    
    video = YouTube(link)
    
    thumbnail_url = video.thumbnail_url
    
    urllib.request.urlretrieve(thumbnail_url, "thumbnail.jpg")
    thumbnail_image = Image.open("thumbnail.jpg").resize((325, 200), Image.ANTIALIAS) 
    
    img = ImageTk.PhotoImage(thumbnail_image)
    video_thumbnail_image_label.configure(image = img)
    video_thumbnail_image_label.configure(image = img)
    os.remove("thumbnail.jpg")
    
    video_title = "Video Title: " + video.title + '\n'
    video_author = "Video By: " + video.author + '\n'
    video_view_count = "Video View Count: " + str(video.views) + '\n'
    video_publish_date = "Video Publish Date: " + str(video.publish_date) + '\n'
    video_id = "Video ID: " + video.video_id + '\n'
    
    if len(video_title) >= 53:
        video_title = video_title[:52] + "..."

    video_title_label.configure(text = video_title)
    video_author_label.configure(text = video_author)
    video_view_label.configure(text = video_view_count)
    video_publish_label.configure(text = video_publish_date)
    video_id_label.configure(text = video_id)
    
    stop_thread.clear()

# %%
tab = ttk.Notebook(video_audio_frame)
# tab.place(anchor = 'nw', width = 600, height = 135)
tab.pack(fill = BOTH, expand = 1)

# %%
video_frame = Frame(video_audio_frame, height = 135)
audio_text_frame = Frame(video_audio_frame)

# %%
video_frame.pack()
audio_text_frame.pack()

# %%
tab.add(video_frame, text = "Download Video Only")
tab.add(audio_text_frame, text = "Download Video and Text Convert")

# %%
video_download_ongoing_label = Label(video_frame, text = "", relief = SUNKEN, bd = 1, width = 650, height = 1)
video_download_ongoing_label.place(anchor = "s", relx = 0.5, rely = 1)

# %%
def start_thread_process(num):

    if num == 1:
        video_download_thread = threading.Thread(target = lambda:download_video(urlInput.get()))
        loading_text_thread = threading.Thread(target = lambda:loading_text(1))
        video_download_thread.start()
        loading_text_thread.start()
        
    elif num == 2:
        audio_text_donwload_thread = threading.Thread(target = lambda:convert_video_to_text(urlInput.get(), video_language_cb.current(), audio_slicing_constraint_cb.current()))
        loading_text_thread = threading.Thread(target = lambda:loading_text(2))
        audio_text_donwload_thread.start() 
        loading_text_thread.start()

# %%
def download_video(link):
    global url_done_btn
    global download_video_btn
    global convert_video_to_text_btn
    
    url_done_btn["state"] = DISABLED
    download_video_btn["state"] = DISABLED
    convert_video_to_text_btn["state"] = DISABLED
    
    
    only_video_download_folder = "Downloaded Videoes"
    
    if not os.path.isdir(only_video_download_folder):
        os.mkdir(only_video_download_folder)
    
    video = YouTube(link)
    my_video = video.streams.get_highest_resolution()
    my_video.download(only_video_download_folder)
    
    stop_thread.set()
    
    url_done_btn["state"] = ACTIVE
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    video_download_ongoing_label.configure(text = "Your Video is Successfully Downloaded")

# %%
def loading_text(num):
    global video_download_ongoing_label
    global audio_text_download_ongoing_label
    
    if num == 1:
        st = "Video Downloading has started...Please Wait---"
        while True:
            video_download_ongoing_label.configure(text = st + "/")
            video_download_ongoing_label.configure(text = st + "-")
            video_download_ongoing_label.configure(text = st + "\\")
            
            if stop_thread.is_set():
                break
                
    elif num == 2:
        st = "Video to Text Conversion ongoing...Please Wait---"
        while True:
            audio_text_download_ongoing_label.configure(text = st + "/")
            audio_text_download_ongoing_label.configure(text = st + "-")
            audio_text_download_ongoing_label.configure(text = st + "\\")
            
            if stop_thread.is_set():
                break

# %%
download_video_btn = Button(video_frame, text = "Download Only Video", command = lambda:start_thread_process(1), state = DISABLED)
download_video_btn.place(anchor = "center", relx = .5, rely = .5)

# %%
choose_video_language_label = Label(audio_text_frame, text = "Choose Video Language: ")
choose_video_language_label.place(anchor = "nw", relx = .02, rely = .2)

video_language = StringVar()

video_language_cb = ttk.Combobox(audio_text_frame, width = 20, textvariable = video_language, state="readonly")
video_language_cb['values'] = (
    ' Bengali - India', 
    ' Bengali - Bangladesh',
    ' Hindi',
    ' English - India',
    ' English - America', 
    ' English - Britain'
)
video_language_cb.place(anchor = "w", relx = .05, rely = .5)
video_language_cb.current(1)
# Out:
# ''

# %%
choose_video_language_label = Label(audio_text_frame, text = "Choose Audio Slicing Technique: ")
choose_video_language_label.place(anchor = "nw", relx = .32, rely = .2)

audio_slicing = StringVar()

audio_slicing_constraint_cb = ttk.Combobox(audio_text_frame, width = 30, textvariable = audio_slicing, state="readonly")
audio_slicing_constraint_cb['values'] = (
    ' Silence based - 500ms (recommended)', 
    ' Silence based - 250ms',
    ' Silence based - 200ms',
    ' Silence based - 100ms',
    ' Silence based - 50ms', 
    ' Time based - 1.5 min',
    ' Time based - 1 min',
    ' Time based - 50 sec',
    ' Time based - 40sec',
    ' Time based - 20sec'
)
audio_slicing_constraint_cb.place(anchor = "center", relx = .5, rely = .5)
audio_slicing_constraint_cb.current(0)
# Out:
# ''

# %%
audio_text_download_ongoing_label = Label(audio_text_frame, text = "", relief = SUNKEN, bd = 1, width = 650, height = 1)
audio_text_download_ongoing_label.place(anchor = "s", relx = 0.5, rely = 1)

# %%
convert_video_to_text_btn = Button(audio_text_frame, text = "Download Video\n And\n Convert to Text", command = lambda:start_thread_process(2), state = DISABLED)
convert_video_to_text_btn.place(anchor = "e", relx = .9, rely = .5)

# %%
def convert_video_to_text(link, lang_index, chunk_index):
    
    global url_done_btn
    global download_video_btn
    global convert_video_to_text_btn
    
    url_done_btn["state"] = DISABLED
    download_video_btn["state"] = DISABLED
    convert_video_to_text_btn["state"] = DISABLED
    
    video = YouTube(link)
    
    folder_name = video.title.translate(str.maketrans('', '', string.punctuation))
    
    folder_name = folder_name[:50].strip()
    
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    
    my_video = video.streams.get_highest_resolution().download(folder_name)
    os.rename(my_video, os.path.join(folder_name, "video.mp4"))
    
    
    downloaded_video = moviepy.editor.VideoFileClip(os.path.join(folder_name, "video.mp4"))
   
    
    audio = downloaded_video.audio
    audio.write_audiofile(os.path.join(folder_name, "audio.wav"))
    
    whole_text_pronounce = get_large_audio_transcription(folder_name, os.path.join(folder_name, "audio.wav"), lang_index, chunk_index)
    
    if(lang_index == 2):
        string_divide = whole_text_pronounce.split("<---|---|--->")
        
        text_filename_1 = os.path.join(folder_name, "final(pronounce).txt")
    
        f1 = open(text_filename_1, "x", encoding="utf-8")
        f1 = open(text_filename_1, "r+", encoding="utf-8")
        f1.write(string_divide[0])
        f1.close()
        
        translated_hindi_text = hindi_translation(string_divide[1])
        
        text_filename_2 = os.path.join(folder_name, "final(hindi_translated).txt")
    
        f2 = open(text_filename_2, "x", encoding="utf-8")
        f2 = open(text_filename_2, "r+", encoding="utf-8")
        f2.write(translated_hindi_text)
        f2.close()
        
    else:
        
        text_filename = os.path.join(folder_name, "final(pronounce).txt")
    
        f = open(text_filename, "x", encoding="utf-8")
        f = open(text_filename, "r+", encoding="utf-8")
        f.write(whole_text_pronounce)
        f.close()
    
     
    
    stop_thread.set()
    
    url_done_btn["state"] = ACTIVE
    download_video_btn["state"] = ACTIVE
    convert_video_to_text_btn["state"] = ACTIVE
    
    audio_text_download_ongoing_label.configure(text = "Your Video-Audio is Successfully Converted to Text")

# %%
def get_large_audio_transcription(parent_folder, audio_path, lang_index, chunk_index):
    
    rec = sr.Recognizer()
    sound = AudioSegment.from_wav(audio_path)
    
    if(chunk_index == 0):
        chunks = split_on_silence(sound, min_silence_len = 500, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 1):
        chunks = split_on_silence(sound, min_silence_len = 250, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 2):
        chunks = split_on_silence(sound, min_silence_len = 200, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 3):
        chunks = split_on_silence(sound, min_silence_len = 100, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 4):
        chunks = split_on_silence(sound, min_silence_len = 50, silence_thresh = sound.dBFS-14, keep_silence = 500)
    elif(chunk_index == 5):
        chunks = make_chunks(sound, 90000)
    elif(chunk_index == 6):
        chunks = make_chunks(sound, 60000)
    elif(chunk_index == 6):
        chunks = make_chunks(sound, 50000)
    elif(chunk_index == 7):
        chunks = make_chunks(sound, 40000)
    else:
        chunks = make_chunks(sound, 20000)
    
    folder_name = "audio_chunks"
    folder_path = os.path.join(parent_folder, folder_name)
    if not os.path.isdir(folder_path):
        os.mkdir(folder_path)
    whole_text = ""
    whole_hindi_text = ""
    for i, audio_chunk in enumerate(chunks, start = 1):
        chunk_filename = os.path.join(folder_path, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = rec.record(source)
            
            try:
                if(lang_index == 0):
                    text = rec.recognize_google(audio_listened, language = "bn-IN")
                elif(lang_index == 1):
                    text = rec.recognize_google(audio_listened, language = "bn-BD")
                elif(lang_index == 2):
                    text = rec.recognize_google(audio_listened, language = "en-IN")
                    text_trans = rec.recognize_google(audio_listened, language = "hi-IN")
                elif(lang_index == 3):
                    text = rec.recognize_google(audio_listened, language = "en-IN")
                elif(lang_index == 4):
                    text = rec.recognize_google(audio_listened, language = "en-US")
                else:
                    text = rec.recognize_google(audio_listened, language = "en-GB")
                
            except sr.UnknownValueError as e:
                print("Error: str(e)")
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text + '\n\n'
                if(lang_index == 2):
                    whole_hindi_text += text_trans + '\n\n'
                        
    if(lang_index == 2):
        final_text = whole_text + '\n\n<---|---|--->\n\n' + whole_hindi_text
        return final_text
    
    # return the text for all chunks detected
    return whole_text

# %%
def hindi_translation(hindi_text_whole):
    translated_hindi_to_eng_whole = ""
    hindi_text_whole_divided_list = hindi_text_whole.split("\n\n")
    
    for i in range(len(hindi_text_whole_divided_list)):
        
        translator = Translator(service_urls=['translate.googleapis.com'])
        print(hindi_text_whole_divided_list[i])
        trans = translator.translate(hindi_text_whole_divided_list[i], dest='en')
        translated_hindi_to_eng_whole += trans.text + '\n\n'
    
    return translated_hindi_to_eng_whole

# %%
root.mainloop()
# Out:
# MoviePy - Writing audio in Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio.wav
# MoviePy - Done.
# result2:
# {   'alternative': [   {   'confidence': 0.77668989,
#                            'transcript': 'মেকআপ করতে পারে না মেকআপ এ তুমি '
#                                          'এক্কেবারে নতুন'},
#                        {   'transcript': 'মেকআপ করতে পারেনা মেকআপ এ তুমি '
#                                          'এক্কেবারে নতুন'},
#                        {   'transcript': 'মেকাপ করতে পারেনা মেকআপ এ তুমি '
#                                          'এক্কেবারে নতুন'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk1.wav : মেকআপ করতে পারে না মেকআপ এ তুমি এক্কেবারে নতুন.
# result2:
# {   'alternative': [   {   'confidence': 0.81509829,
#                            'transcript': 'কি কি প্রোডাক্ট কিনবে তা ভাবছো'},
#                        {'transcript': 'কি কি প্রোডাক্ট কিনবে তা ভাবছ'},
#                        {'transcript': 'কি কি প্রোডাক্ট কিনবে তা ভাব'},
#                        {'transcript': 'ঠিকই প্রডাক্ট কিনবে তা ভাবছো'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk2.wav : কি কি প্রোডাক্ট কিনবে তা ভাবছো.
# result2:
# {   'alternative': [   {   'confidence': 0.82034874,
#                            'transcript': 'আজকের ভিডিওটা তুমি একবার দেখে'},
#                        {'transcript': 'তুমি একবার দেখে'},
#                        {'transcript': 'আজকে ভিডিওটা তুমি একবার দেখে'},
#                        {'transcript': 'ভিডিওটা তুমি একবার দেখে'},
#                        {'transcript': 'আজকের ভিডিওটা তুমি একবার'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk3.wav : আজকের ভিডিওটা তুমি একবার দেখে.
# result2:
# {   'alternative': [   {   'confidence': 0.80976701,
#                            'transcript': 'আজ আমি তোমাদের একেবারে সব থেকে কম '
#                                          'খরচের মধ্যে সুন্দর করে রেডি করে'},
#                        {   'transcript': 'তোমাদের একেবারে সব থেকে কম খরচের '
#                                          'মধ্যে সুন্দর করে রেডি করে'},
#                        {   'transcript': 'আজ আমি তোমাদের একেবারে সব থেকে কম '
#                                          'খরচের মধ্যে সুন্দর করে রেডি করে দেব'},
#                        {   'transcript': 'আজ আমি তোমাদের একেবারে সব থেকে কম '
#                                          'খরচের মধ্যে সুন্দর করে রেডি করে '
#                                          'দেবো'},
#                        {   'transcript': 'তোমাদের একেবারে সব থেকে কম খরচের '
#                                          'মধ্যে সুন্দর করে রেডি করে দেব'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk4.wav : আজ আমি তোমাদের একেবারে সব থেকে কম খরচের মধ্যে সুন্দর করে রেডি করে.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.68113565,
#                            'transcript': 'তাহলে তোমার জন্য'},
#                        {'transcript': 'তাহলে তোমারই জন্য'},
#                        {'transcript': 'তোমার জন্য'},
#                        {'transcript': 'তাহলে তোমার'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk6.wav : তাহলে তোমার জন্য.
# result2:
# {   'alternative': [   {   'confidence': 0.81672323,
#                            'transcript': 'কোথায় যেন মেকআপ এই জন্য প্রচন্ড '
#                                          'রকমের প্রয়োজনীয় জিনিস সেগুলো শুধু '
#                                          'মাত্র আগামী তোমাদের বলে দেব'},
#                        {   'transcript': 'কোথায় যেন মেকআপ এই জন্য প্রচন্ড '
#                                          'রকমের প্রয়োজনীয় জিনিস সেগুলো শুধু '
#                                          'মাত্র আগামী তোমাদের বলে দেবো'},
#                        {   'transcript': 'কোথায় যেন মেকআপ এই জন্য প্রচন্ড '
#                                          'রকমের প্রয়োজনীয় জিনিস সেগুলো শুধু '
#                                          'মাত্র আগামী তোমাদের'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk7.wav : কোথায় যেন মেকআপ এই জন্য প্রচন্ড রকমের প্রয়োজনীয় জিনিস সেগুলো শুধু মাত্র আগামী তোমাদের বলে দেব.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.81175339,
#                            'transcript': 'মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় '
#                                          'জিনিস মানে ফার্স্ট যেটা এস টাইপের '
#                                          'যেটা জিনিস সেটা হচ্ছে একটা ভালো '
#                                          'মশ্চার'},
#                        {   'transcript': 'মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় '
#                                          'জিনিস মানে ফার্স্ট যেটা এস টাইপের '
#                                          'যেটা জিনিস সেটা হচ্ছে একটা ভাল মোস্ট '
#                                          'ওয়ে'},
#                        {   'transcript': 'মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় '
#                                          'জিনিস মানে ফার্স্ট যেটা এস টাইপের '
#                                          'যেটা জিনিস সেটা হচ্ছে একটা ভালো '
#                                          'মরচরা'},
#                        {   'transcript': 'মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় '
#                                          'জিনিস মানে ফার্স্ট যেটা এস টাইপের '
#                                          'যেটা জিনিস সেটা হচ্ছে একটা ভালো '
#                                          'মশ্চুয়াল'},
#                        {   'transcript': 'মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় '
#                                          'জিনিস মানে ফার্স্ট যেটা এস টাইপের '
#                                          'যেটা জিনিস সেটা হচ্ছে একটা ভালো '
#                                          'মশ্চুয়ে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk9.wav : মেকআপ করতে সবথেকে যেটা প্রয়োজনীয় জিনিস মানে ফার্স্ট যেটা এস টাইপের যেটা জিনিস সেটা হচ্ছে একটা ভালো মশ্চার.
# result2:
# {   'alternative': [   {   'confidence': 0.7333101,
#                            'transcript': 'স্কিনের জন্য নিয়ে নিতে হবে'},
#                        {'transcript': 'স্ক্রিনের জন্য নিয়ে নিতে হবে'},
#                        {'transcript': 'নিতে হবে'},
#                        {   'transcript': 'তোমাকে কিন্তু ভালো একটা মর্যাদার '
#                                          'স্কিনের জন্য নিয়ে নিতে হবে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk10.wav : স্কিনের জন্য নিয়ে নিতে হবে.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {'confidence': 0.71275949, 'transcript': 'লাইক এইটা'},
#                        {'transcript': 'লাইট এইটা'},
#                        {'transcript': 'এইটা'},
#                        {'transcript': 'লাইট'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk12.wav : লাইক এইটা.
# result2:
# {   'alternative': [   {   'confidence': 0.81620789,
#                            'transcript': 'তোমার যদি তিন টাইপ হয়ে থাকে ড্রাই '
#                                          'তাহলে তুমি ইউজ করো বিভিন্ন রকমের '
#                                          'ময়েশ্চার্য ল্যাকমি লেকমি মাস চলে '
#                                          'যাচ্ছে'},
#                        {   'transcript': 'তোমার যদি তিন টাইপ হয়ে থাকে ড্রাই '
#                                          'তাহলে তুমি ইউজ করো বিভিন্ন রকমের '
#                                          'ময়েশ্চার্য ল্যাকমি ল্যাকমি মাস চলে '
#                                          'যাচ্ছে'},
#                        {   'transcript': 'তোমার যদি তিন টাইপ হয়ে থাকে ড্রাই '
#                                          'তাহলে তুমি ইউজ করো বিভিন্ন রকমের '
#                                          'ময়েশ্চার্য ল্যাকমি ল্যাকমি'},
#                        {   'transcript': 'তোমার যদি তিন টাইপ হয়ে থাকে ড্রাই '
#                                          'তাহলে তুমি ইউজ করো বিভিন্ন রকমের '
#                                          'ময়েশ্চার্য ল্যাকমি'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk13.wav : তোমার যদি তিন টাইপ হয়ে থাকে ড্রাই তাহলে তুমি ইউজ করো বিভিন্ন রকমের ময়েশ্চার্য ল্যাকমি লেকমি মাস চলে যাচ্ছে.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.81018108,
#                            'transcript': 'ইউজ করতেই হবে গরমকালের সময় আমরা '
#                                          'অনেকেই এ ক্ষেত্রে বাদ দিয়ে দিই '
#                                          'মশ্চারাইজার'},
#                        {   'transcript': 'ইউজ করতেই হবে গরমকালের সময় আমরা '
#                                          'অনেকেই এই ক্ষেত্রে বাদ দিয়ে দিই '
#                                          'মশ্চারাইজার'},
#                        {   'transcript': 'ইউজ করতেই হবে গরমকালের সময় আমরা '
#                                          'অনেকেই এক্ষেত্রে বাদ দিয়ে দিই '
#                                          'মশ্চারাইজার'},
#                        {   'transcript': 'ইউজ করতেই হবে গরমকালের সময় আমরা '
#                                          'অনেকেই এ ক্ষেত্রে বাদ দিয়ে দিই '
#                                          'মশ্চারাই'},
#                        {   'transcript': 'ইউজ করতেই হবে গরমকালের সময় আমরা '
#                                          'অনেকেই এ ক্ষেত্রে বাদ দিয়ে দিই '
#                                          'মশ্চার'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk15.wav : ইউজ করতেই হবে গরমকালের সময় আমরা অনেকেই এ ক্ষেত্রে বাদ দিয়ে দিই মশ্চারাইজার.
# result2:
# {   'alternative': [   {'confidence': 0.68629837, 'transcript': 'ফাউন্ডেশন'},
#                        {   'transcript': 'ফাউন্ডেশন বসাবো সে ক্ষেত্রে কিন্তু '
#                                          'ফাউন্ডেশন'},
#                        {'transcript': 'সে ক্ষেত্রে কিন্তু ফাউন্ডেশন'},
#                        {'transcript': 'ফাউন্ডেশান'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk16.wav : ফাউন্ডেশন.
# result2:
# {   'alternative': [   {   'confidence': 0.76654011,
#                            'transcript': 'বর্ষা থেকে অনেক সমস্যা হয় তাই জন্য'},
#                        {'transcript': 'বসে থেকে অনেক সমস্যা হয় তাই জন্য'},
#                        {'transcript': 'বর্ষা থেকে অনেক সমস্যা হয় তাই যেন'},
#                        {'transcript': 'বসে থেকে অনেক সমস্যা হয় তাই যেন'},
#                        {'transcript': 'বর্ষা থেকে অনেক সমস্যা হয় তার জন্য'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk17.wav : বর্ষা থেকে অনেক সমস্যা হয় তাই জন্য.
# result2:
# {   'alternative': [   {   'confidence': 0.81617433,
#                            'transcript': 'যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে '
#                                          'রেখো তারপরে কিন্তু মেকআপের একটা একটা '
#                                          'করে আমি স্টেট গুলো এখন তোমাদের'},
#                        {   'transcript': 'যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে '
#                                          'রেখো তারপরে কিন্তু মেকআপের একটা একটা '
#                                          'করে আমি স্টেটগুলো এখন তোমাদের'},
#                        {   'transcript': 'যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে '
#                                          'রেখো তারপরে কিন্তু মেকআপের একটা একটা '
#                                          'করে আমি স্টেপ গুলো এখন তোমাদের'},
#                        {   'transcript': 'যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে '
#                                          'রেখো তারপরে কিন্তু মেকআপের একটা একটা '
#                                          'করে আমি স্টেট গুলো এখন'},
#                        {   'transcript': 'যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে '
#                                          'রেখো তারপরে কিন্তু মেকআপের একটা একটা '
#                                          'করে আমি স্টেটগুলো এখন'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk18.wav : যে কোন একটা মশ্চার্যরা যা অবশ্যই ঘরে রেখো তারপরে কিন্তু মেকআপের একটা একটা করে আমি স্টেট গুলো এখন তোমাদের.
# result2:
# {   'alternative': [   {'confidence': 0.82696593, 'transcript': 'বলে দিচ্ছি'},
#                        {'transcript': 'বলে'},
#                        {'transcript': 'দিচ্ছি'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk19.wav : বলে দিচ্ছি.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.82384413,
#                            'transcript': 'একটা ভালো আমাদের প্রাইমার দরকার'},
#                        {'transcript': 'একটা ভাল আমাদের প্রাইমার দরকার'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk21.wav : একটা ভালো আমাদের প্রাইমার দরকার.
# result2:
# {   'alternative': [   {   'confidence': 0.80845296,
#                            'transcript': 'প্রাইমার কিন্তু স্কিনের মধ্যে '
#                                          'মেকআপটাকে লং lasting করে মেকআপ টাকে '
#                                          'ধরে রাখতে সাহায্য করে'},
#                        {   'transcript': 'প্রাইমার কিন্তু স্কিনের মধ্যে '
#                                          'মেকআপটাকে লং লাস্টিং করে মেকআপ টাকে '
#                                          'ধরে রাখতে সাহায্য করে'},
#                        {   'transcript': 'প্রাইমার কিন্তু স্কিনের মধ্যে '
#                                          'মেকআপটাকে লং lasting করে মেকআপ টা কে '
#                                          'ধরে রাখতে সাহায্য করে'},
#                        {   'transcript': 'প্রাইমার কিন্তু স্কিনের মধ্যে '
#                                          'মেকআপটাকে লং lasting করে মেকআপটাকে '
#                                          'ধরে রাখতে সাহায্য করে'},
#                        {   'transcript': 'প্রাইমার কিন্তু স্কিনের মধ্যে '
#                                          'মেকআপটাকে লং lasting করে মেকআপ টাকে '
#                                          'ধরে রাখতে সাহায্য'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk22.wav : প্রাইমার কিন্তু স্কিনের মধ্যে মেকআপটাকে লং lasting করে মেকআপ টাকে ধরে রাখতে সাহায্য করে.
# result2:
# {   'alternative': [   {   'confidence': 0.80536401,
#                            'transcript': 'এটা একটা ভালো প্রাইমার যদি তোমাদের '
#                                          'কাছে অলরেডি থেকে থাকে তাহলে তোমরা '
#                                          'সেই প্রাইমারি ইউজ করো'},
#                        {   'transcript': 'এটা একটা ভালো প্রাইমার যদি তোমাদের '
#                                          'কাছে অলরেডি থেকে থাকে তাহলে তোমরা '
#                                          'সেই প্রাইমারি ইউজ'},
#                        {   'transcript': 'এটা একটা ভালো প্রাইমার যদি তোমাদের '
#                                          'কাছে অলরেডি থেকে থাকে তাহলে তোমরা '
#                                          'সেই প্রাইমার ইউজ করো'},
#                        {   'transcript': 'এটা একটা ভালো প্রাইমার যদি তোমাদের '
#                                          'কাছে অলরেডি থেকে থাকে তাহলে তোমরা '
#                                          'সেই প্রাইমারি ইউজ কর'},
#                        {   'transcript': 'এটা একটা ভালো প্রাইমার যদি তোমাদের '
#                                          'কাছে অলরেডি থেকে থাকে তাহলে তোমরা '
#                                          'সেই প্রাইমার ইউজ'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk23.wav : এটা একটা ভালো প্রাইমার যদি তোমাদের কাছে অলরেডি থেকে থাকে তাহলে তোমরা সেই প্রাইমারি ইউজ করো.
# result2:
# {   'alternative': [   {   'confidence': 0.80638635,
#                            'transcript': 'তবে আজকে যে তোমার ভিডিওটা শুধুমাত্র '
#                                          'দিনের জন্য যারা মেকআপ কিট রেডি করছো '
#                                          'সবে মাত্র'},
#                        {   'transcript': 'তবে আজকে যে তোমার ভিডিওটা শুধুমাত্র '
#                                          'দিনের জন্য যারা মেকআপ কিট রেডি করছো '
#                                          'সবেমাত্র'},
#                        {   'transcript': 'তবে আজকে যে তোমার ভিডিওটা শুধুমাত্র '
#                                          'দিনের জন্য যারা মেকআপ কিট রেডি করছো '
#                                          'সবে'},
#                        {   'transcript': 'তবে আজকে যে তোমার ভিডিওটা শুধুমাত্র '
#                                          'দিনের জন্য যারা মেকআপ কিট রেডি করছো '
#                                          'সয়ে মাত্র'},
#                        {   'transcript': 'তবে আজকের যে তোমার ভিডিওটা শুধুমাত্র '
#                                          'দিনের জন্য যারা মেকআপ কিট রেডি করছো '
#                                          'সবে মাত্র'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk24.wav : তবে আজকে যে তোমার ভিডিওটা শুধুমাত্র দিনের জন্য যারা মেকআপ কিট রেডি করছো সবে মাত্র.
# result2:
# {   'alternative': [   {   'confidence': 0.81995004,
#                            'transcript': 'কি ভাবছো মেকাপের জন্য কি কি '
#                                          'প্রোডাক্ট কিনবে তাদের জন্য তো '
#                                          'তাদেরকে আমি সাজেস্ট করবো তোমরা হাতের '
#                                          'কাছে রাখো একটা অ্যালোভেরা জেল'},
#                        {   'transcript': 'কি ভাবছো মেকাপের জন্য কি কি '
#                                          'প্রোডাক্ট কিনবে তাদের জন্য তো '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা হাতের '
#                                          'কাছে রাখো একটা অ্যালোভেরা জেল'},
#                        {   'transcript': 'কি ভাবছো মেকাপের জন্য কি কি '
#                                          'প্রোডাক্ট কিনবে তাদের জন্য তো '
#                                          'তাদেরকে আমি সাজেস্ট করবো তোমরা হাতের '
#                                          'কাছে রাখো একটা অ্যালোবেরা জেল'},
#                        {   'transcript': 'কি ভাবছো মেকাপের জন্য কি কি '
#                                          'প্রোডাক্ট কিনবে তাদের জন্য তো '
#                                          'তাদেরকে আমি সাজেস্ট করবো তোমরা হাতের '
#                                          'কাছে রাখো একটা অ্যালোভেরার জেল'},
#                        {   'transcript': 'কি ভাবছো মেকাপের জন্য কি কি '
#                                          'প্রোডাক্ট কিনবে তাদের জন্য তো '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা হাতের '
#                                          'কাছে রাখো একটা অ্যালোভেরার জেল'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk25.wav : কি ভাবছো মেকাপের জন্য কি কি প্রোডাক্ট কিনবে তাদের জন্য তো তাদেরকে আমি সাজেস্ট করবো তোমরা হাতের কাছে রাখো একটা অ্যালোভেরা জেল.
# result2:
# {   'alternative': [   {   'confidence': 0.81191063,
#                            'transcript': 'অ্যালোভেরা জেল বিভিন্ন রকম কাজে ইউজ '
#                                          'করা হয় লাইক হেয়ার ইউজ করা যায় '
#                                          'স্ক্রিনে ইউজ করা'},
#                        {   'transcript': 'অ্যালোভেরা জেল বিভিন্ন রকম কাজে ইউজ '
#                                          'করা হয় লাইক হেয়ার ইউজ করা যায় '
#                                          'স্ক্রিনে ইউজ করা যায়'},
#                        {   'transcript': 'অ্যালোভেরা জেল বিভিন্ন রকম কাজে '
#                                          'ব্যবহার করা হয় লাইক হেয়ার ইউজ করা '
#                                          'যায় স্ক্রিনে ইউজ করা'},
#                        {   'transcript': 'অ্যালোভেরা জেল বিভিন্ন রকম কাজে ইউজ '
#                                          'করা হয় লাইক হেয়ার ইউজ করা যায় '
#                                          'স্ক্রীনে ইউজ করা'},
#                        {   'transcript': 'অ্যালোভেরা জেল বিভিন্ন রকম কাজে '
#                                          'ব্যবহার করা হয় লাইক হেয়ার ইউজ করা '
#                                          'যায় স্ক্রিনে ইউজ করা যায়'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk26.wav : অ্যালোভেরা জেল বিভিন্ন রকম কাজে ইউজ করা হয় লাইক হেয়ার ইউজ করা যায় স্ক্রিনে ইউজ করা.
# result2:
# {   'alternative': [   {   'confidence': 0.67786986,
#                            'transcript': 'ইউজ করে দেখাচ্ছি'},
#                        {'transcript': 'প্রাইমার হিসেবে ইউজ করে দেখাচ্ছি'},
#                        {'transcript': 'ইউস করে দেখাচ্ছি'},
#                        {'transcript': 'ইউজ করে দেখা'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk27.wav : ইউজ করে দেখাচ্ছি.
# result2:
# {   'alternative': [   {   'confidence': 0.7934972,
#                            'transcript': 'আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম '
#                                          'আমি নিজেও পার্সোনালি ভীষণভাবে প্রচার '
#                                          'করি অ্যালোভেরা জেল'},
#                        {   'transcript': 'আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম '
#                                          'আমি নিজেও পার্সোনালি ভীষণভাবে প্রচার '
#                                          'করি অ্যালোভেরা'},
#                        {   'transcript': 'আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম '
#                                          'আমি নিজেও পার্সোনালি ভীষণভাবে প্রচার '
#                                          'করি এলোভেরা জেল'},
#                        {   'transcript': 'আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম '
#                                          'আমি নিজেও পার্সোনালি ভীষণভাবে প্রচার '
#                                          'করি এলোভেরা'},
#                        {   'transcript': 'আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম '
#                                          'আমি নিজেও পার্সোনালি ভীষণ ভাবে '
#                                          'প্রচার করি এলোভেরা জেল'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk28.wav : আর শুধুমাত্র তোমাদের দেখাচ্ছি টাইম আমি নিজেও পার্সোনালি ভীষণভাবে প্রচার করি অ্যালোভেরা জেল.
# result2:
# {   'alternative': [   {   'confidence': 0.81833178,
#                            'transcript': 'এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে '
#                                          'মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে '
#                                          'নেব এটা আমাদের স্কিনকে শুটিং করে '
#                                          'দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে '
#                                          'তার সাথে সাথে কিন্তু পুরোপুরি হবে'},
#                        {   'transcript': 'এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে '
#                                          'মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে '
#                                          'নেব এটা আমাদের স্কিন কে শুটিং করে '
#                                          'দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে '
#                                          'তার সাথে সাথে কিন্তু পুরোপুরি হবে'},
#                        {   'transcript': 'এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে '
#                                          'মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে '
#                                          'নেব এটা আমাদের স্কিনকে শুটিং করে '
#                                          'দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে '
#                                          'তার সাথে সাথে পুরোপুরি হবে'},
#                        {   'transcript': 'এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে '
#                                          'মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে '
#                                          'নেব এটা আমাদের স্কিনকে শুটিং করে '
#                                          'দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে '
#                                          'তার সাথে সাথে কিন্তু পুরোপুরি'},
#                        {   'transcript': 'এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে '
#                                          'মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে '
#                                          'নেব এটা আমাদের স্কিনকে শুটিং করে '
#                                          'দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে '
#                                          'তার সাথে সাথে কিন্তু পুরোপুরি ভাবে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk29.wav : এই অ্যালোভেরা জেলটা আমরা ফুলের মধ্যে মশ্চারাইজার এর পরের স্টেপেই লাগিয়ে নেব এটা আমাদের স্কিনকে শুটিং করে দেবে ভীষণভাবে একটা কুলিং এফেক্ট দেবে তার সাথে সাথে কিন্তু পুরোপুরি হবে.
# result2:
# {   'alternative': [   {   'confidence': 0.82696599,
#                            'transcript': 'প্রাইমারির কাজ করবে'},
#                        {'transcript': 'প্রাইমারির কাজ'},
#                        {'transcript': 'প্রাইমারি কাজ করবে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk30.wav : প্রাইমারির কাজ করবে.
# result2:
# {   'alternative': [   {   'confidence': 0.81803775,
#                            'transcript': 'এর পরে দেখতে মানে প্রাইমারি '
#                                          'কলেজস্ট্রিতে আমাদের ইউজ করতে হবে '
#                                          'একটা ভালো ফাউন্ডেশন'},
#                        {   'transcript': 'এরপরে দেখতে মানে প্রাইমারি '
#                                          'কলেজস্ট্রিতে আমাদের ইউজ করতে হবে '
#                                          'একটা ভালো ফাউন্ডেশন'},
#                        {   'transcript': 'এর পরে দেখতে মানে প্রাইমারি '
#                                          'কলেজস্ট্রিতে আমাদের ইউজ করতে হবে '
#                                          'একটা ভাল ফাউন্ডেশন'},
#                        {   'transcript': 'এর পরে দেখতে মানে প্রাইমারি '
#                                          'কলেজস্ট্রিতে আমাদের ইউজ করতে হবে। '
#                                          'একটা ভালো ফাউন্ডেশন'},
#                        {   'transcript': 'এর পরে দেখতে মানে প্রাইমারি '
#                                          'কলেজস্ট্রিতে আমাদের ইউজ করতে হবে '
#                                          'একটা ভালো ফাউন্ড'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk31.wav : এর পরে দেখতে মানে প্রাইমারি কলেজস্ট্রিতে আমাদের ইউজ করতে হবে একটা ভালো ফাউন্ডেশন.
# result2:
# {   'alternative': [   {   'confidence': 0.79386002,
#                            'transcript': 'যেটা আমাদের মধ্যে খুব সুন্দর ভাবে '
#                                          'কাভারের'},
#                        {'transcript': 'যেটা আমাদের খুব সুন্দর ভাবে কাভারের'},
#                        {   'transcript': 'যেটা আমাদের মধ্যে খুব সুন্দর ভাবে '
#                                          'কভারের'},
#                        {   'transcript': 'যেটা আমাদের মধ্যে খুব সুন্দরভাবে '
#                                          'কাভারের'},
#                        {   'transcript': 'যেটা আমাদের মধ্যে খুব সুন্দর ভাবে '
#                                          'কাভার'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk32.wav : যেটা আমাদের মধ্যে খুব সুন্দর ভাবে কাভারের.
# result2:
# {   'alternative': [   {   'confidence': 0.78610396,
#                            'transcript': 'এখন অনেকে হয়তো ভাবছো যে দিদি আমাদের '
#                                          'কেন কোন'},
#                        {   'transcript': 'এখন অনেকে হয়তো ভাবছো যে দিদি আমাদের '
#                                          'কেন'},
#                        {   'transcript': 'এখনো অনেকে হয়তো ভাবছো যে দিদি '
#                                          'আমাদের কেন কোন'},
#                        {   'transcript': 'এখন অনেকে হয়তো ভাবছো যে দিদি আমাদের '
#                                          'কেন কোনো'},
#                        {   'transcript': 'এখনো অনেকে হয়তো ভাবছো যে দিদি '
#                                          'আমাদের কেন'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk33.wav : এখন অনেকে হয়তো ভাবছো যে দিদি আমাদের কেন কোন.
# result2:
# {   'alternative': [   {   'confidence': 0.76026767,
#                            'transcript': 'আকালে তারিখকে বাতান এর কথা না বলি '
#                                          'কেন ফাউন্ডেশনে চলে গেল'},
#                        {   'transcript': 'আকালে তারিখকে বাতান এর কথা না বলে '
#                                          'কেন ফাউন্ডেশনে চলে গেল'},
#                        {   'transcript': 'আকালে তারিখ কে বকাঞ্চি লাগে কথা না '
#                                          'বলি কেন ফাউন্ডেশনে চলে গেল'},
#                        {   'transcript': 'আকালে তারিখ কে বকাঞ্চি লাগে কথা না '
#                                          'বলে কেন ফাউন্ডেশনে চলে গেল'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk34.wav : আকালে তারিখকে বাতান এর কথা না বলি কেন ফাউন্ডেশনে চলে গেল.
# result2:
# {   'alternative': [   {   'confidence': 0.81446028,
#                            'transcript': 'দেখো এর মধ্যে কারণ আছে কারণ আজকের '
#                                          'ভিডিওটা যেহেতু শুধুমাত্র নতুনদের '
#                                          'জন্য মেকাপের যারা নতুন তাদের জন্য'},
#                        {   'transcript': 'তা দেখো এর মধ্যে কারণ আছে কারণ আজকের '
#                                          'ভিডিওটা যেহেতু শুধুমাত্র নতুনদের '
#                                          'জন্য মেকাপের যারা নতুন তাদের জন্য'},
#                        {   'transcript': 'দেখো এর মধ্যে কারণ আছে কারণ আজকের '
#                                          'ভিডিওটা যেহেতু শুধুমাত্র নতুনদের '
#                                          'জন্য মেকআপের যারা নতুন তাদের জন্য'},
#                        {   'transcript': 'তা দেখো এর মধ্যে কারণ আছে কারণ আজকের '
#                                          'ভিডিওটা যেহেতু শুধুমাত্র নতুনদের '
#                                          'জন্য মেকআপের যারা নতুন তাদের জন্য'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk35.wav : দেখো এর মধ্যে কারণ আছে কারণ আজকের ভিডিওটা যেহেতু শুধুমাত্র নতুনদের জন্য মেকাপের যারা নতুন তাদের জন্য.
# result2:
# {   'alternative': [   {   'confidence': 0.82026052,
#                            'transcript': 'নতুন কাকিমা রেগুলার তোমরা মেকআপ করো '
#                                          'না তাদেরকে আমি এতকিছু সাজেস্ট করবো '
#                                          'না কালার এগুলো আমি তোমাদের সাজেস্ট '
#                                          'করবো না তোমাদের জন্য দেখো আমি যখন '
#                                          'এক্কেবারে মেকআপ এই নতুন ছিলাম আমি'},
#                        {   'transcript': 'নতুন কাকিমা রেগুলার তোমরা মেকআপ করো '
#                                          'না তাদেরকে আমি এতকিছু সাজেস্ট করবো '
#                                          'না কালার এগুলো আমি তোমাদের সাজেস্ট '
#                                          'করবো না তোমাদের জন্য আমি যখন '
#                                          'এক্কেবারে মেকআপ এই নতুন ছিলাম আমি'},
#                        {   'transcript': 'নতুন কাকিমা রেগুলার তোমরা মেকআপ করো '
#                                          'না তাদেরকে আমি এতকিছু সাজেস্ট করবো '
#                                          'না কালার এগুলো আমি তোমাদের সাজেস্ট '
#                                          'করবো না তোমাদের জন্য দেখো আমি যখন '
#                                          'এক্কেবারে নতুন ছিলাম আমি'},
#                        {   'transcript': 'নতুন কাকিমা রেগুলার তোমরা মেকআপ করো '
#                                          'না তাদেরকে আমি এতকিছু সাজেস্ট করবো '
#                                          'না কালার এগুলো আমি তোমাদের সাজেস্ট '
#                                          'করবো না তোমাদের জন্য দেখো আমি যখন '
#                                          'এক্কেবারে মেকআপ এই নতুন ছিলাম'},
#                        {   'transcript': 'নতুন কাকিমা রেগুলার তোমরা মেকআপ করো '
#                                          'না তাদেরকে আমি এতকিছু সাজেস্ট করবো '
#                                          'না কালার এগুলো আমি তোমাদের সাজেস্ট '
#                                          'করবো না তোমাদের জন্য আমি যখন '
#                                          'এক্কেবারে মেকআপ এই নতুন ছিলাম'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk36.wav : নতুন কাকিমা রেগুলার তোমরা মেকআপ করো না তাদেরকে আমি এতকিছু সাজেস্ট করবো না কালার এগুলো আমি তোমাদের সাজেস্ট করবো না তোমাদের জন্য দেখো আমি যখন এক্কেবারে মেকআপ এই নতুন ছিলাম আমি.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.80869043,
#                            'transcript': 'লিখেছিলাম নিজের কাছে একটা ফাউন্ডেশন '
#                                          'সেটা দিয়ে আমি আমার ফুল ফেসটাকে'},
#                        {   'transcript': 'রেখেছিলাম নিজের কাছে একটা ফাউন্ডেশন '
#                                          'সেটা দিয়ে আমি আমার ফুল ফেসটাকে'},
#                        {   'transcript': 'লিখেছিলাম নিজের কাছে একটা ফাউন্ডেশন '
#                                          'সেটা দিয়ে আমি আমার ফুল ফেস'},
#                        {   'transcript': 'রেখেছিলাম নিজের কাছে একটা ফাউন্ডেশন '
#                                          'সেটা দিয়ে আমি আমার ফুল ফেস'},
#                        {   'transcript': 'লিখেছিলাম নিজের কাছে একটা ফাউন্ডেশন '
#                                          'সেটাতে আমি আমার ফুল ফেসটাকে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk38.wav : লিখেছিলাম নিজের কাছে একটা ফাউন্ডেশন সেটা দিয়ে আমি আমার ফুল ফেসটাকে.
# result2:
# {   'alternative': [   {   'confidence': 0.82696593,
#                            'transcript': 'সুন্দর করে কাভার করে নি'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk39.wav : সুন্দর করে কাভার করে নি.
# result2:
# {   'alternative': [   {   'confidence': 0.80337507,
#                            'transcript': 'তাও তোমরা যদি দেখতে চাও জেনে আমরা '
#                                          'কিভাবে আমার ডাক্তারদের হাইড করব'},
#                        {   'transcript': 'তাও তোমরা যদি দেখতে চাও জেনে আমরা '
#                                          'কিভাবে আমার ডাক্তারকে হাইড করব'},
#                        {   'transcript': 'তাও তোমরা যদি দেখতে চাও জেনে আমরা '
#                                          'কিভাবে আমার ডাক্তারদের হাইড করবো'},
#                        {   'transcript': 'তাও তোমরা যদি দেখতে চাও জেনে আমরা '
#                                          'কিভাবে আমার ডাক্তারকে হাইট করবো'},
#                        {   'transcript': 'তাও তোমরা যদি দেখতে চাও জেনে আমরা '
#                                          'কিভাবে আমার ডাক্তারকে হাইড করবো'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk40.wav : তাও তোমরা যদি দেখতে চাও জেনে আমরা কিভাবে আমার ডাক্তারদের হাইড করব.
# result2:
# {   'alternative': [   {   'confidence': 0.82633877,
#                            'transcript': 'আর কিছু কি করে করব তাহলে নিশ্চয় '
#                                          'তোমরা আমার চ্যানেল এরকম আরো অনেক '
#                                          'ভিডিও পেয়ে যাবে যেগুলোতে আমি '
#                                          'তোমাদের সঠিক'},
#                        {   'transcript': 'আর কিছু কি করে করব তাহলে নিশ্চয় '
#                                          'তোমরা আমার চ্যানেল এরকম আরো অনেক '
#                                          'ভিডিও পেয়ে যাবে যেগুলোতে আমি '
#                                          'তোমাদের সঠিকভাবে'},
#                        {   'transcript': 'আর কিছু কি করে করব তাহলে নিশ্চয় '
#                                          'তোমরা আমার চ্যানেল এরকম আরো অনেক '
#                                          'ভিডিও পেয়ে যাবে যেগুলো আমি তোমাদের '
#                                          'সঠিক'},
#                        {   'transcript': 'আর কিছু কি করে করব তাহলে নিশ্চয়ই '
#                                          'তোমরা আমার চ্যানেল এরকম আরো অনেক '
#                                          'ভিডিও পেয়ে যাবে যেগুলোতে আমি '
#                                          'তোমাদের সঠিক'},
#                        {   'transcript': 'আর কিছু কি করে করব তাহলে নিশ্চয় '
#                                          'তোমরা আমার চ্যানেল এরকম আরো অনেক '
#                                          'ভিডিও পেয়ে যাবে। যেগুলোতে আমি '
#                                          'তোমাদের সঠিক'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk41.wav : আর কিছু কি করে করব তাহলে নিশ্চয় তোমরা আমার চ্যানেল এরকম আরো অনেক ভিডিও পেয়ে যাবে যেগুলোতে আমি তোমাদের সঠিক.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.81473196,
#                            'transcript': 'আর অল স্কিন টাইপের জন্য যদি আমার '
#                                          'কাছে তোমরা ফাউন্ডেশন সাজেশন চাও '
#                                          'তাহলে আমি বলে দেবো'},
#                        {   'transcript': 'আর অল স্কিন টাইপের জন্য যদি আমার '
#                                          'কাছে তোমরা ফাউন্ডেশন সাজেশন চাও '
#                                          'তাহলে আমি বলে দিব ফাউন্ডেশন ইজ '
#                                          'বেস্ট'},
#                        {   'transcript': 'আর অল স্কিন টাইপের জন্য যদি আমার '
#                                          'কাছে তোমরা ফাউন্ডেশন সাজেশন চাও '
#                                          'তাহলে আমি বলে দেবো ফাউন্ডেশন ইজ '
#                                          'বেস্ট'},
#                        {   'transcript': 'আর অল স্কিন টাইপের জন্য যদি আমার '
#                                          'কাছে তোমরা ফাউন্ডেশন সাজেশন চাও '
#                                          'তাহলে আমি বলে দিব ফাউন্ডেশন'},
#                        {   'transcript': 'আর অল স্কিন টাইপের জন্য যদি আমার '
#                                          'কাছে তোমরা ফাউন্ডেশন সাজেশন চাও '
#                                          'তাহলে আমি বলে দিব ফাউন্ডেশন ইজ'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk43.wav : আর অল স্কিন টাইপের জন্য যদি আমার কাছে তোমরা ফাউন্ডেশন সাজেশন চাও তাহলে আমি বলে দেবো.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {'confidence': 0.67449284, 'transcript': 'স্কিনের জন্য'},
#                        {'transcript': 'স্কিনের জন'},
#                        {'transcript': 'নরমাল স্কিনের জন্য'},
#                        {'transcript': 'নরমাল স্কিনের জন'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk45.wav : স্কিনের জন্য.
# result2:
# {   'alternative': [   {   'confidence': 0.80919766,
#                            'transcript': 'তো যারা অরিজিৎ সিং তারা কিন্তু এটা '
#                                          'নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন '
#                                          'টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে '
#                                          'পারো কিন্তু যাদের ড্রাই এক্স'},
#                        {   'transcript': 'তো যারা অরিজিৎ সিং তারা কিন্তু এটা '
#                                          'নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন '
#                                          'টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে '
#                                          'পারো কিন্তু যাদের দায়'},
#                        {   'transcript': 'তো যারা অরিজিৎ সিং তারা কিন্তু এটা '
#                                          'নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন '
#                                          'টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে '
#                                          'পারো কিন্তু যাদের দায় এক্স'},
#                        {   'transcript': 'তো যারা অরিজিৎ সিং তারা কিন্তু এটা '
#                                          'নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন '
#                                          'টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে '
#                                          'পারো কিন্তু যাদের ড্রাই'},
#                        {   'transcript': 'তো যারা অরিজিৎ সিং তারা কিন্তু এটা '
#                                          'নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন '
#                                          'টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে '
#                                          'পারে কিন্তু যাদের দায়'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk46.wav : তো যারা অরিজিৎ সিং তারা কিন্তু এটা নিশ্চিন্তপুর নিউজ করতে পারে অল স্কিন টাচ কিন্তু নিশ্চিন্তে কোন ইউজ করতে পারো কিন্তু যাদের ড্রাই এক্স.
# result2:
# {   'alternative': [   {   'confidence': 0.6812498,
#                            'transcript': 'ফাউন্ডেশন রয়েছে'},
#                        {'transcript': 'ফাউন্ডেশন'},
#                        {'transcript': 'ফাউন্ডেশনে'},
#                        {'transcript': 'ফাউন্ডেশনের'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk47.wav : ফাউন্ডেশন রয়েছে.
# result2:
# {   'alternative': [   {   'confidence': 0.79795969,
#                            'transcript': 'লেকমি ফাউন্ডেশন রয়েছে তোমরা এই '
#                                          'ফাউন্ডেশনগুলো ইউজ করতে পারো'},
#                        {   'transcript': 'লেকমি ফাউন্ডেশন রয়েছে তোমরা এই '
#                                          'ফাউন্ডেশন গুলো ইউজ করতে পারো'},
#                        {   'transcript': 'লেকমি ফাউন্ডেশন রয়েছে সো তোমরা এই '
#                                          'ফাউন্ডেশন গুলো ইউজ করতে পারো'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk48.wav : লেকমি ফাউন্ডেশন রয়েছে তোমরা এই ফাউন্ডেশনগুলো ইউজ করতে পারো.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.81693447,
#                            'transcript': 'অবশ্যই আমাদের মেকআপ কিটের মধ্যে '
#                                          'রাখতে হবে'},
#                        {   'transcript': 'অবশ্যই আমাদের মেকআপ কিট এর মধ্যে '
#                                          'রাখতে হবে'},
#                        {'transcript': 'আমাদের মেকআপ কিটের মধ্যে রাখতে হবে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk50.wav : অবশ্যই আমাদের মেকআপ কিটের মধ্যে রাখতে হবে.
# result2:
# {   'alternative': [   {   'confidence': 0.8207283,
#                            'transcript': 'ফাউন্ডেশন ইউজ করো কনসিলের ইউজ করে '
#                                          'সেটাকে সুন্দর করে সেট করার জন্য '
#                                          'মেকাপের একটা সুন্দর করে কাভারেজ '
#                                          'দেওয়ার জন্য দরকার হয় আমাদের'},
#                        {   'transcript': 'ফাউন্ডেশন ইউজ করো কনসিলের ইউজ করে '
#                                          'সেটাকে সুন্দর করে সেট করার জন্য '
#                                          'মেকআপের একটা সুন্দর করে কাভারেজ '
#                                          'দেওয়ার জন্য দরকার হয় আমাদের'},
#                        {   'transcript': 'ফাউন্ডেশন ইউস করো ক্যানসিলের ইউজ করে '
#                                          'সেটাকে সুন্দর করে সেট করার জন্য '
#                                          'মেকআপের একটা সুন্দর করে কাভারেজ '
#                                          'দেওয়ার জন্য দরকার হয় আমাদের'},
#                        {   'transcript': 'ফাউন্ডেশন ইউজ করো কনসিলের ইউজ করে '
#                                          'সেটাকে সুন্দর করে সেট করার জন্য '
#                                          'মেকাপের একটা সুন্দর করে কাভারেজ '
#                                          'দেওয়ার জন্য দরকার হয়'},
#                        {   'transcript': 'ফাউন্ডেশন ইউজ করো কনসিলের ইউজ করে '
#                                          'সেটাকে সুন্দর করে সেট করার জন্য '
#                                          'মেকআপের একটা সুন্দর করে কাভারেজ '
#                                          'দেওয়ার জন্য দরকার হয়'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk51.wav : ফাউন্ডেশন ইউজ করো কনসিলের ইউজ করে সেটাকে সুন্দর করে সেট করার জন্য মেকাপের একটা সুন্দর করে কাভারেজ দেওয়ার জন্য দরকার হয় আমাদের.
# result2:
# {   'alternative': [   {   'confidence': 0.80208385,
#                            'transcript': 'কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস '
#                                          'দেয় কারণ এটার মধ্যে একটা অয়েল '
#                                          'কন্ট্রোল প্রপার্টি রয়েছে'},
#                        {   'transcript': 'কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস '
#                                          'দেয় কারণ এটার মধ্যে একটা অয়েল '
#                                          'কন্ট্রোল প্রপার্টিজ রয়েছে'},
#                        {   'transcript': 'কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস '
#                                          'দেয় কারণ এটার মধ্যে একটা অয়েল '
#                                          'কন্ট্রোল প্রোপারটিজ রয়েছে'},
#                        {   'transcript': 'কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস '
#                                          'দেয় কারণ এটার মধ্যে একটা অয়েল '
#                                          'কন্ট্রোল প্রোপার্টিজ রয়েছে'},
#                        {   'transcript': 'কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস '
#                                          'দেয় কারণ এটার মধ্যে একটা অয়েল '
#                                          'কন্ট্রোল প্রপার্টি'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk52.wav : কম্প্যাক্টিভ তো কিডনি কম্প্যাকটিস দেয় কারণ এটার মধ্যে একটা অয়েল কন্ট্রোল প্রপার্টি রয়েছে.
# result2:
# {   'alternative': [   {   'confidence': 0.81658882,
#                            'transcript': 'আমি আমার যারা বন্ধুরা চাই প্রত্যেকে '
#                                          'তাদের করবো তোমরা ফিল্ম কম্প্যাকটি '
#                                          'ইউজ করো কারণ এটা কিন্তু'},
#                        {   'transcript': 'আমি আমার যারা বন্ধুরা চাই প্রত্যেকে '
#                                          'তাদের করবো তোমরা ফিল্ম কম্প্যাকটি '
#                                          'ইউজ কর কারণ এটা কিন্তু'},
#                        {   'transcript': 'আমি আমার যারা বন্ধুরা চাই প্রত্যেকে '
#                                          'তাদের করবো তোমরা ফিল্ম কম্প্যাকটি '
#                                          'ব্যবহার করো কারণ এটা কিন্তু'},
#                        {   'transcript': 'আমি আমার যারা বন্ধুরা চাই প্রত্যেকে '
#                                          'তাদের করবো তোমরা ফিল্ম কম্প্যাকটি '
#                                          'ইউজ করো কারণ এটা'},
#                        {   'transcript': 'আমি আমার যারা বন্ধুরা চাই প্রত্যেকে '
#                                          'তাদের করবো তোমরা ফিল্ম কম্প্যাকটি '
#                                          'ইউজ করো কারন এটা কিন্তু'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk53.wav : আমি আমার যারা বন্ধুরা চাই প্রত্যেকে তাদের করবো তোমরা ফিল্ম কম্প্যাকটি ইউজ করো কারণ এটা কিন্তু.
# result2:
# {   'alternative': [   {   'confidence': 0.82310021,
#                            'transcript': 'মুখের ঘামটাকে বাইরে বের হতে দেয় না '
#                                          'তো কিডনি কম্প্যাক্টটা খুব ভালোভাবে '
#                                          'কিন্তু মেকআপ কে লক করে দেয়। যারা '
#                                          'একটু এডভান্স লেভেলের মেকআপ করতে চাও '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা লুজ '
#                                          'পাউডার সেট করে দেন তোমরা'},
#                        {   'transcript': 'মুখের ঘামটাকে বাইরে বের হতে দেয় না '
#                                          'তো কিডনি কম্প্যাক্টটা খুব ভালোভাবে '
#                                          'কিন্তু মেকআপ কে লক করে দেয়। যারা '
#                                          'একটু এডভান্স লেভেলের মেকআপ করতে চাও '
#                                          'তাদেরকে আমি সাজেস্ট করবো তোমরা লুজ '
#                                          'পাউডার সেট করে দেন তোমরা'},
#                        {   'transcript': 'মুখের ঘামটাকে বাইরে বের হতে দেয় না '
#                                          'তো কিডনি কম্প্যাক্টটা খুব ভালোভাবে '
#                                          'কিন্তু মেকাপ কে লক করে দেয়। যারা '
#                                          'একটু এডভান্স লেভেলের মেকআপ করতে চাও '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা লুজ '
#                                          'পাউডার সেট করে দেন তোমরা'},
#                        {   'transcript': 'মুখের ঘামটাকে বাইরে বের হতে দেয় না '
#                                          'তো কিডনি কম্প্যাক্টটা খুব ভালোভাবে '
#                                          'কিন্তু মেকআপ কে লক করে দেয়। যারা '
#                                          'একটু এডভান্স লেভেলের মেকআপ করতে চাও '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা লুজ '
#                                          'পাউডার সেট করে'},
#                        {   'transcript': 'মুখের ঘামটাকে বাইরে বের হতে দেয় না '
#                                          'তো কিডনি কম্প্যাক্টটা খুব ভালোভাবে '
#                                          'কিন্তু মেকআপ কে লক করে দেয়। যারা '
#                                          'একটু এডভান্স লেভেলের মেকআপ করতে চাও '
#                                          'তাদেরকে আমি সাজেস্ট করব তোমরা লুজ '
#                                          'পাউডার সেট করে তোমরা'}],
#     'final': True}
# ...
#                                          'জন্য আর একটা ভিডিও প্রেজেন্ট করে '
#                                          'সেখানে কিন্তু তোমাদের সবকিছু সাজেস্ট '
#                                          'করে দেবো সব থেকে বেশি দরকার সেটা '
#                                          'হচ্ছে একটা হাইলাই'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk119.wav : আর চাও তাহলে সে ক্ষেত্রে আমি তোমাদের জন্য আর একটা ভিডিও প্রেজেন্ট করে সেখানে কিন্তু তোমাদের সবকিছু সাজেস্ট করে দেবো সব থেকে বেশি দরকার সেটা হচ্ছে একটা হাইলাইট.
# result2:
# {   'alternative': [   {   'confidence': 0.82021773,
#                            'transcript': 'আমরা প্রত্যেকেই আমাদের মুখটা তাদের '
#                                          'সাইন করে আমাদের মুখটা যাতে খুব '
#                                          'সুন্দর লাগে দেখতে'},
#                        {   'transcript': 'আমরা প্রত্যেকে আমাদের মুখটা তাদের '
#                                          'সাইন করে আমাদের মুখটা যাতে খুব '
#                                          'সুন্দর লাগে দেখতে'},
#                        {   'transcript': 'আমরা প্রত্যেকেই আমাদের মুখটা তাদের '
#                                          'সাইন করে আমাদের মুক্তাদির খুব সুন্দর '
#                                          'লাগে দেখতে'},
#                        {   'transcript': 'আমরা প্রত্যেকেই আমাদের মুখটা তাদের '
#                                          'সাইন করে আমাদের মুখটা যাতে খুব '
#                                          'সুন্দর লাগে'},
#                        {   'transcript': 'আমরা প্রত্যেকে আমাদের মুখটা তাদের '
#                                          'সাইন করে আমাদের মুখটা যাতে খুব '
#                                          'সুন্দর লাগে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk120.wav : আমরা প্রত্যেকেই আমাদের মুখটা তাদের সাইন করে আমাদের মুখটা যাতে খুব সুন্দর লাগে দেখতে.
# result2:
# []
# Error: str(e)
# result2:
# {   'alternative': [   {   'confidence': 0.69262761,
#                            'transcript': 'তুই বিউটি হাইলাই'},
#                        {'transcript': 'তুই বিউটি হাইরা'},
#                        {'transcript': 'হাইলেটেড তুই বিউটি হাইলাই'},
#                        {'transcript': 'তুই বিউটি হাইলাইট'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk122.wav : তুই বিউটি হাইলাই.
# result2:
# {   'alternative': [   {   'confidence': 0.81280339,
#                            'transcript': 'তুই হায়রে একটা আমিও পার্সোনাল ইউজ '
#                                          'করে অনেকদিন ধরে ইউজ করছি আর একটা '
#                                          'হাইলা এটা নিয়ে না'},
#                        {   'transcript': 'তুই হায়রে একটা আমিও পার্সোনাল ইউজ '
#                                          'করে অনেক দিন ধরে ইউজ করছি আর একটা '
#                                          'হাইলা এটা নিয়ে না'},
#                        {   'transcript': 'তুই হায়রে একটা আমিও পার্সোনাল ইউজ '
#                                          'করে অনেকদিন ধরে ইউজ করছি আর একটা হাই '
#                                          'এটা নিয়ে না'},
#                        {   'transcript': 'তুই হায়রে একটা আমিও পার্সোনাল ইউজ '
#                                          'করে অনেকদিন ধরে ইউজ করছি আর একটা '
#                                          'হাইলা টা নিয়ে না'},
#                        {   'transcript': 'তুই হায়রে একটা আমিও পার্সোনাল ইউজ '
#                                          'করে অনেকদিন ধরে ইউজ করছি আর একটা '
#                                          'হাইলা এটা নিয়ে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk123.wav : তুই হায়রে একটা আমিও পার্সোনাল ইউজ করে অনেকদিন ধরে ইউজ করছি আর একটা হাইলা এটা নিয়ে না.
# result2:
# {   'alternative': [   {   'confidence': 0.82489467,
#                            'transcript': 'অনেক অনেক দিন যায় আমি তো রেগুলার '
#                                          'মেকআপ করি তারপর আমরা এতদিন যাই তাহলে '
#                                          'তোমরা যারা এতখানিও মেকআপ করো'},
#                        {   'transcript': 'অনেক অনেক অনেক দিন যায় আমি তো '
#                                          'রেগুলার মেকআপ করি তারপর আমরা এতদিন '
#                                          'যাই তাহলে তোমরা যারা এতখানিও মেকআপ '
#                                          'করো'},
#                        {   'transcript': 'অনেক অনেক দিন যায় আমি তো রেগুলার '
#                                          'মেকআপ করি তারপর আমরা এতদিন যাই তালে '
#                                          'তোমরা যারা এতখানিও মেকআপ করো'},
#                        {   'transcript': 'অনেক অনেক দিন যায় আমি তো রেগুলার '
#                                          'মেকআপ করি তারপর আমরা এতদিন যাই তাহলে '
#                                          'তোমরা যারা এতখানিও মেকআপ কর'},
#                        {   'transcript': 'অনেক অনেক অনেক দিন যায় আমি তো '
#                                          'রেগুলার মেকআপ করি তারপর আমরা এতদিন '
#                                          'যাই তাহলে তোমরা যারা এতখানিও মেকআপ '
#                                          'কর'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk124.wav : অনেক অনেক দিন যায় আমি তো রেগুলার মেকআপ করি তারপর আমরা এতদিন যাই তাহলে তোমরা যারা এতখানিও মেকআপ করো.
# result2:
# {   'alternative': [   {   'confidence': 0.81386644,
#                            'transcript': 'তাদের বুঝতেই পারছ তাদের কতদিন যাবে '
#                                          'একটা হাই-টা নিয়ে অনেক দিন যাবে এটা '
#                                          'কিন্তু'},
#                        {   'transcript': 'তাদের বুঝতেই পারছো তাদের কতদিন যাবে '
#                                          'একটা হাই-টা নিয়ে অনেক দিন যাবে এটা '
#                                          'কিন্তু'},
#                        {   'transcript': 'তাদের বুঝতেই পারছ তাদের কতদিন যাবে '
#                                          'একটা হাই-টা নিয়ে অনেক দিন যাবে আর '
#                                          'এটা কিন্তু'},
#                        {   'transcript': 'তাদের বুঝতেই পারছ তাদের কতদিন যাবে '
#                                          'একটা হাই-টা নিয়ে অনেকদিন যাবেনা এটা '
#                                          'কিন্তু'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk125.wav : তাদের বুঝতেই পারছ তাদের কতদিন যাবে একটা হাই-টা নিয়ে অনেক দিন যাবে এটা কিন্তু.
# result2:
# {   'alternative': [   {   'confidence': 0.78074849,
#                            'transcript': 'ভীষণ সস্তার মধ্যে পেয়ে'},
#                        {'transcript': 'ভীষণ স্বস্তার মধ্যে পেয়ে'},
#                        {'transcript': 'পেয়ে'},
#                        {'transcript': 'মধ্যে পেয়ে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk126.wav : ভীষণ সস্তার মধ্যে পেয়ে.
# result2:
# {   'alternative': [   {   'confidence': 0.82504755,
#                            'transcript': 'আর শেষের দিকে যেটা আমাদের দরকার হয় '
#                                          'সেটা হচ্ছে একটা সেটিং স্প্রে দরকার '
#                                          'হয়'},
#                        {   'transcript': 'আর শেষের দিকে যেটা আমাদের দরকার হয় '
#                                          'সেটা হচ্ছে একটা সেটিং স্প্রের দরকার '
#                                          'হয়'},
#                        {   'transcript': 'আর শেষের দিকে যেটা আমাদের দরকার হয় '
#                                          'সেটা হচ্ছে একটা সেটিংস দরকার হয়'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk127.wav : আর শেষের দিকে যেটা আমাদের দরকার হয় সেটা হচ্ছে একটা সেটিং স্প্রে দরকার হয়.
# result2:
# {   'alternative': [   {   'confidence': 0.81831539,
#                            'transcript': 'আমি তোমাদের সাজেস্ট করবো কোন দরকার '
#                                          'নেই সেটিংস করার কারণ এমনি কিন্তু '
#                                          'মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস '
#                                          'পেয়ে আমি যেটা করে থাকি আমার ভীষণ '
#                                          'ভালো লাগে আর এটাতে কোন আমার মুখের '
#                                          'মধ্যে প্রেসারও করে না সেটা হচ্ছে'},
#                        {   'transcript': 'আমি তোমাদের সাজেস্ট করবো কোন দরকার '
#                                          'নেই সেটিংস করার কারণ এমনি কিন্তু '
#                                          'মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস '
#                                          'পেয়ে আমি যেটা করে থাকি আমার ভীষণ '
#                                          'ভালো লাগে আর এটাতে কোন আমার মুখের '
#                                          'মধ্যে প্রেসার পড়াবে সেটা হচ্ছে'},
#                        {   'transcript': 'আমি তোমাদের সাজেস্ট করব কোন দরকার '
#                                          'নেই সেটিংস করার কারণ এমনি কিন্তু '
#                                          'মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস '
#                                          'পেয়ে আমি যেটা করে থাকি আমার ভীষণ '
#                                          'ভালো লাগে আর এটাতে কোন আমার মুখের '
#                                          'মধ্যে প্রেসারও করে না সেটা হচ্ছে'},
#                        {   'transcript': 'আমি তোমাদের সাজেস্ট করবো কোন দরকার '
#                                          'নেই সেটিংস করার কারণ এমনি কিন্তু '
#                                          'মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস '
#                                          'পেয়ে আমি যেটা করে থাকি আমার ভীষণ '
#                                          'ভালো লাগে আর এটাতে কোন আমার মুখের '
#                                          'মধ্যে প্রেসার করে না সেটা হচ্ছে'},
#                        {   'transcript': 'আমি তোমাদের সাজেস্ট করবো কোন দরকার '
#                                          'নেই সেটিংস করার কারণ এমনি কিন্তু '
#                                          'মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস '
#                                          'পেয়ে আমি যেটা করে থাকি আমার ভীষণ '
#                                          'ভালো লাগে আর এটাতে কোন আমার মুখের '
#                                          'মধ্যে প্রেসার পড়ায় না সেটা হচ্ছে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk128.wav : আমি তোমাদের সাজেস্ট করবো কোন দরকার নেই সেটিংস করার কারণ এমনি কিন্তু মেকআপ সুন্দর থেকে যায় তা আগে সেটিংস পেয়ে আমি যেটা করে থাকি আমার ভীষণ ভালো লাগে আর এটাতে কোন আমার মুখের মধ্যে প্রেসারও করে না সেটা হচ্ছে.
# result2:
# {   'alternative': [   {   'confidence': 0.79771996,
#                            'transcript': 'এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা '
#                                          'আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা '
#                                          'একটা বোতলের মধ্যে নিয়ে নাও বাড়িতে '
#                                          'স্পেল বোতলে পাওয়া যায়'},
#                        {   'transcript': 'এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা '
#                                          'আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা '
#                                          'একটা বোতলের মধ্যে নিয়ে পাওয়া যায়'},
#                        {   'transcript': 'এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা '
#                                          'আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা '
#                                          'একটা বোতলের মধ্যে নিয়ে নাও বাড়িতে '
#                                          'এক্সপের বোতলে পাওয়া যায়'},
#                        {   'transcript': 'এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা '
#                                          'আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা '
#                                          'একটা বোতলের মধ্যে নিয়ে নাও বাড়িতে '
#                                          'স্পেল বোতলে পাওয়া'},
#                        {   'transcript': 'এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা '
#                                          'আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা '
#                                          'একটা বোতলের মধ্যে নিয়ে নাও বাড়িতে '
#                                          'এক্সপের বোতলে পাওয়া'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk129.wav : এরকম রোজ ওয়াটার মুখের মধ্যে মানেটা আবার গুলাবাড়ি রোজ ওয়াটারকে তোমরা একটা বোতলের মধ্যে নিয়ে নাও বাড়িতে স্পেল বোতলে পাওয়া যায়.
# result2:
# {   'alternative': [   {   'confidence': 0.78638774,
#                            'transcript': 'তোমার মেকআপ কে খুব সুন্দর ভাবে লক '
#                                          'করে দেবে'},
#                        {   'transcript': 'তোমার মেকআপ কে খুব সুন্দরভাবে লক করে '
#                                          'দেবে'},
#                        {   'transcript': 'তোমার মেকআপ কে খুব সুন্দর ভাবে ব্লক '
#                                          'করে দেবে'},
#                        {   'transcript': 'তোমার মেকআপ কে খুব সুন্দরভাবে ব্লক '
#                                          'করে দেবে'},
#                        {'transcript': 'তোমার মেকআপ কে খুব সুন্দর ভাবে লক করে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk130.wav : তোমার মেকআপ কে খুব সুন্দর ভাবে লক করে দেবে.
# result2:
# {   'alternative': [   {   'confidence': 0.80586904,
#                            'transcript': 'হ্যাঁ তোমাদের হয়তো সেটিং অনেক ঘন্টা '
#                                          'পর্যন্ত লাস্টিং থাকে'},
#                        {   'transcript': 'হ্যাঁ তোমাদের হয়তো সেটিং অনেক ঘন্টা '
#                                          'পর্যন্ত লাফিং থাকে'},
#                        {   'transcript': 'হ্যাঁ তোমাদের হয়তো সেটিং অনেক ঘন্টা '
#                                          'পর্যন্ত লাফটিং থাকে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk131.wav : হ্যাঁ তোমাদের হয়তো সেটিং অনেক ঘন্টা পর্যন্ত লাস্টিং থাকে.
# result2:
# {   'alternative': [   {   'confidence': 0.81939119,
#                            'transcript': 'দেখেছো হয়তো লাফিং থাকবে না কিন্তু '
#                                          'ভীষণভাবে তোমাকে রিপ্লেস ফিল করবে '
#                                          'মেকআপ টাও কিন্তু সুন্দর করে'},
#                        {   'transcript': 'দেখেছো হয়তো লাফিং থাকবে না কিন্তু '
#                                          'ভীষণভাবে তোমাকে রিপ্লেস ফিল করবে '
#                                          'মেকাপটাও কিন্তু সুন্দর করে'},
#                        {   'transcript': 'দেখেছো হয়তো লাফিং থাকবে না কিন্তু '
#                                          'ভীষণ ভাবে তোমাকে রিপ্লেস ফিল করবে '
#                                          'মেকআপ টাও কিন্তু সুন্দর করে'},
#                        {   'transcript': 'দেখেছো হয়তো লাফিং থাকবে না কিন্তু '
#                                          'ভীষণভাবে তোমাকে রিপ্লেস ফিল করবে '
#                                          'মেকআপ টা কিন্তু সুন্দর করে'},
#                        {   'transcript': 'দেখেছো হয়তো লাফিং থাকবে না কিন্তু '
#                                          'ভীষণভাবে তোমাকে রিপ্লেস ফিল করবে '
#                                          'মেকআপটাও কিন্তু সুন্দর করে'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk132.wav : দেখেছো হয়তো লাফিং থাকবে না কিন্তু ভীষণভাবে তোমাকে রিপ্লেস ফিল করবে মেকআপ টাও কিন্তু সুন্দর করে.
# result2:
# {   'alternative': [   {   'confidence': 0.80325383,
#                            'transcript': 'পেট করে রাখবে'},
#                        {'transcript': 'করে রাখবে'},
#                        {'transcript': 'পেট করে রাখবে।'},
#                        {'transcript': 'করে রাখবে।'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk133.wav : পেট করে রাখবে.
# result2:
# {   'alternative': [   {   'confidence': 0.79343414,
#                            'transcript': 'তো দেখতে থাকো চলো মেকআপ'},
#                        {'transcript': 'তো দেখতে থাকুক চলো মেকআপ'},
#                        {'transcript': 'তো দেখতে থাকো চলো মেকআপ শিখিস তিনি'},
#                        {'transcript': 'তো দেখতে থাকো চলো মেকআপ শিখি'},
#                        {'transcript': 'তো দেখতে থাকো চলো মেকআপ শিখিস'}],
#     'final': True}
# Makeup Korte Ki Ki Lage  মেকআপ করতে কি কি লাগে  Sa\audio_chunks\chunk134.wav : তো দেখতে থাকো চলো মেকআপ.
# result2:
# []
# Error: str(e)
# result2:
# []
# Error: str(e)
# result2:
# []
# Error: str(e)
# result2:
# []
# Error: str(e)
